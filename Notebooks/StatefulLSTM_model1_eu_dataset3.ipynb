# %%
# !pip install -q tensorflow-gpu==2.0.0-alpha0

# %% [markdown]
# ### Get Model files and Datasets from cloud storage

# %%
# from google.colab import files
# files.upload()

# %%
# !wget https://storage.googleapis.com/columbia_applied_deep_learning/demand_forecasting.zip  \
    -O ./demand_forecasting.zip
# Out:
# --2019-05-19 03:52:50--  https://storage.googleapis.com/columbia_applied_deep_learning/demand_forecasting.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.129.128, 2607:f8b0:4001:c07::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.129.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3361698 (3.2M) [application/zip]
# Saving to: ‘./demand_forecasting.zip’
#
# ./demand_forecastin 100%[===================>]   3.21M  --.-KB/s    in 0.06s
#
# 2019-05-19 03:52:50 (50.1 MB/s) - ‘./demand_forecasting.zip’ saved [3361698/3361698]

# %%
import zipfile
local_zip = './demand_forecasting.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('./')
zip_ref.close()

# %%
# !ls -al
# Out:
# total 7284
# drwxr-xr-x 1 root root    4096 May 19 03:38 .
# drwxr-xr-x 1 root root    4096 May 19 03:37 ..
# drwxr-xr-x 1 root root    4096 May 16 16:08 .config
# -rw-r--r-- 1 root root 3361698 May 19 03:13 demand_forecasting.zip
# drwxr-xr-x 2 root root    4096 May 19 03:38 __MACOSX
# -rw-r--r-- 1 root root  189008 May 19 03:52 model1_eu.hdf5
# -rw-r--r-- 1 root root  188968 May 19 03:52 model1_id2.hdf5
# -rw-r--r-- 1 root root  171048 May 19 03:52 model1_th.hdf5
# -rw-r--r-- 1 root root  901416 May 19 03:52 model2_eu.hdf5
# -rw-r--r-- 1 root root  901312 May 19 03:52 model2_id2.hdf5
# -rw-r--r-- 1 root root  901312 May 19 03:52 model2_th.hdf5
# -rw-r--r-- 1 root root  150744 May 19 03:52 model3_eu.hdf5
# -rw-r--r-- 1 root root  150744 May 19 03:52 model3_id2.hdf5
# -rw-r--r-- 1 root root  150744 May 19 03:52 model3_th_exp_120.hdf5
# -rw-r--r-- 1 root root  150744 May 19 03:52 model3_th_exp.hdf5
# -rw-r--r-- 1 root root  142760 May 19 03:52 model3_th.hdf5
# -rw-r--r-- 1 root root    8090 May 19 03:52 Product1-Dataset-th-1year.csv
# -rw-r--r-- 1 root root   12721 May 19 03:52 Product1-Dataset-th-2year.csv
# -rw-r--r-- 1 root root   14346 May 19 03:52 Product2-Dataset-id-2year.csv
# -rw-r--r-- 1 root root   11829 May 19 03:52 Product3-Dataset-eu-2year.csv
# drwxr-xr-x 1 root root    4096 May 15 16:23 sample_data

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import argparse
import os
import platform
import datetime, time
import datetime as dt
import warnings
from IPython.core.display import display, HTML
import tensorflow as tf
from plotly.offline import init_notebook_mode, iplot
from plotly import graph_objs as go
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dense, Dropout, SimpleRNN, Input, LSTM, TimeDistributed,RepeatVector, Flatten
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau,RemoteMonitor
import sys
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import math
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
from tensorflow.keras.models import load_model

plt.style.use('default')
plt.style.use('seaborn-deep')

sns.set(style="whitegrid")
sns.set_context("talk")

# %matplotlib inline
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
checkpoint_dir = './'
model_filename = 'model1_eu.hdf5'
data_filename = 'Product3-Dataset-eu-2year.csv'
train_model = False

# %%
tf.__version__
# Out:
# '2.0.0-alpha0'

# %%
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

# %%
def plotly_df(df, title='', annotations=None, forecast=False):
    """Visualize all the dataframe columns as line plots."""
    common_kw = dict(x=df.index, mode='lines+markers')
    if forecast:
      xaxis = dict(title='Time Steps',type='date', rangeslider=dict(visible=False))
    else:
      xaxis = dict(title='Time Steps',type='date', rangeslider=dict(visible=True))
    
    data = [go.Scatter(y=df[c], name=c,  **common_kw) for c in df.columns]
    layout = dict(title=title, showlegend=True, annotations=annotations, xaxis=xaxis, )
    fig = dict(data=data, layout=layout)
    iplot(fig, show_link=False)

# %%
def create_timeseries_dataset(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var_lag%d(t-%d)' % (j+1, i)) for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var_roll%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var_roll%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
def mean_absolute_percentage_error(y_pred, y_true): 
    return np.mean(np.abs((y_pred - y_true)) / (y_pred+ 1e-7)) * 100

# %% [markdown]
# ### Read and Explore Dataset

# %%
df_raw = pd.read_csv(filepath_or_buffer=data_filename, header=0, names=None, usecols=['date', 'sale_amt'], parse_dates=[0])

# %%
df_raw.index = df_raw.date
df_raw.drop(['date'], inplace=True, axis=1)

# %%
configure_plotly_browser_state()
plotly_df(df_raw, title='Timeseries')
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div id="a54ed234-f97b-437c-9e92-c9a933ed672e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a54ed234-f97b-437c-9e92-c9a933ed672e", [{"mode": "lines+markers", "name": "sale_amt", "x": ["2017-04-06", "2017-04-07", "2017-04-08", "2017-04-09", "2017-04-10", "2017-04-11", "2017-04-12", "2017-04-13", "2017-04-14", "2017-04-15", "2017-04-16", "2017-04-17", "2017-04-18", "2017-04-19", "2017-04-20", "2017-04-21", "2017-04-22", "2017-04-23", "2017-04-24", "2017-04-25", "2017-04-26", "2017-04-27", "2017-04-28", "2017-04-29", "2017-04-30", "2017-05-01", "2017-05-02", "2017-05-03", "2017-05-04", "2017-05-05", "2017-05-06", "2017-05-07", "2017-05-08", "2017-05-09", "2017-05-10", "2017-05-11", "2017-05-12", "2017-05-13", "2017-05-14", "2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-20", "2017-05-21", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-27", "2017-05-28", "2017-05-29", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-03", "2017-06-04", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-10", "2017-06-11", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-17", "2017-06-18", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-24", "2017-06-25", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-01", "2017-07-02", "2017-07-03", "2017-07-04", "2017-07-05", "2017-07-06", "2017-07-07", "2017-07-08", "2017-07-09", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-15", "2017-07-16", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-22", "2017-07-23", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-29", "2017-07-30", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-05", "2017-08-06", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-12", "2017-08-13", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-19", "2017-08-20", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-26", "2017-08-27", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-02", "2017-09-03", "2017-09-04", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-09", "2017-09-10", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-16", "2017-09-17", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-23", "2017-09-24", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-09-30", "2017-10-01", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-07", "2017-10-08", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-14", "2017-10-15", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-21", "2017-10-22", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-28", "2017-10-29", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-04", "2017-11-05", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-11", "2017-11-12", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-18", "2017-11-19", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-23", "2017-11-24", "2017-11-25", "2017-11-26", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-02", "2017-12-03", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-09", "2017-12-10", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-16", "2017-12-17", "2017-12-18", "2017-12-19", "2017-12-20" ...

# %% [markdown]
# Take the first 90 rows away from when the business started as that doesn't represent the pattern

# %%
df_raw =df_raw[90:]

# %%
configure_plotly_browser_state()
plotly_df(df_raw, title='Timeseries')
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div id="be7aaad6-d2f6-45d3-8abe-5f931fae24c8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("be7aaad6-d2f6-45d3-8abe-5f931fae24c8", [{"mode": "lines+markers", "name": "sale_amt", "x": ["2017-07-05", "2017-07-06", "2017-07-07", "2017-07-08", "2017-07-09", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-15", "2017-07-16", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-22", "2017-07-23", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-29", "2017-07-30", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-05", "2017-08-06", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-12", "2017-08-13", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-19", "2017-08-20", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-26", "2017-08-27", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-02", "2017-09-03", "2017-09-04", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-09", "2017-09-10", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-16", "2017-09-17", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-23", "2017-09-24", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-09-30", "2017-10-01", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-07", "2017-10-08", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-14", "2017-10-15", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-21", "2017-10-22", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-28", "2017-10-29", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-04", "2017-11-05", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-11", "2017-11-12", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-18", "2017-11-19", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-23", "2017-11-24", "2017-11-25", "2017-11-26", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-02", "2017-12-03", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-09", "2017-12-10", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-16", "2017-12-17", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-23", "2017-12-24", "2017-12-25", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2017-12-30", "2017-12-31", "2018-01-01", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-06", "2018-01-07", "2018-01-08", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-13", "2018-01-14", "2018-01-15", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-20", "2018-01-21", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-27", "2018-01-28", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-02", "2018-02-03", "2018-02-04", "2018-02-05", "2018-02-06", "2018-02-07", "2018-02-08", "2018-02-09", "2018-02-10", "2018-02-11", "2018-02-12", "2018-02-13", "2018-02-14", "2018-02-15", "2018-02-16", "2018-02-17", "2018-02-18", "2018-02-19", "2018-02-20", "2018-02-21", "2018-02-22", "2018-02-23", "2018-02-24", "2018-02-25", "2018-02-26", "2018-02-27", "2018-02-28", "2018-03-01", "2018-03-02", "2018-03-03", "2018-03-04", "2018-03-05", "2018-03-06", "2018-03-07", "2018-03-08", "2018-03-09", "2018-03-10", "2018-03-11", "2018-03-12", "2018-03-13", "2018-03-14", "2018-03-15", "2018-03-16", "2018-03-17", "2018-03-18", "2018-03-19", "2018-03-20" ...

# %% [markdown]
# ### Baseline Metrics (7-day moving average )

# %%
train, val, test = df_raw['sale_amt'].values[:-14], df_raw['sale_amt'].values[-14:], df_raw['sale_amt'].values[-14:]

# %%
def baseline():
  # Moving average of last few days
  
  train_base = df_raw['sale_amt'][:-14]
  rolling_mean = train_base.rolling(window=7).mean()
  predictions = list()
  predictions = rolling_mean.values[-14:]
  
  for i in range(len(val)):    
    print('>Predicted=%.f, Expected=%.f' % (predictions[i], val[i]))

  df_out = pd.DataFrame(df_raw['sale_amt'][-14:])
  df_out.columns=['Original']
  df_out['Predicted'] = predictions
  
  
  return df_out

# %%
df_out = baseline()
# Out:
# >Predicted=74299, Expected=137733
# >Predicted=60008, Expected=149899
# >Predicted=79410, Expected=89982
# >Predicted=81349, Expected=80733
# >Predicted=82408, Expected=67755
# >Predicted=82408, Expected=0
# >Predicted=82408, Expected=0
# >Predicted=82382, Expected=144153
# >Predicted=96879, Expected=142017
# >Predicted=80311, Expected=72274
# >Predicted=79917, Expected=64477
# >Predicted=79317, Expected=61764
# >Predicted=79317, Expected=0
# >Predicted=79317, Expected=0

# %%
configure_plotly_browser_state()
plotly_df(df_out, title='Baseline Predictions i.e., 7-day moving average for last 14 days', forecast=True)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div id="6df22852-5f28-41b9-a461-ef8dd59f5c49" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6df22852-5f28-41b9-a461-ef8dd59f5c49", [{"mode": "lines+markers", "name": "Original", "x": ["2019-04-01", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14"], "y": [137732.51, 149899.28, 89982.3, 80733.34, 67755.3, 0.0, 0.0, 144153.1, 142016.79, 72274.39, 64476.74, 61764.18, 0.0, 0.0], "type": "scatter", "uid": "e2143ff5-959b-4d4b-a6cb-57a61a7296c9"}, {"mode": "lines+markers", "name": "Predicted", "x": ["2019-04-01", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14"], "y": [74299.03714285704, 60008.26999999989, 79410.0257142856, 81348.63857142847, 82408.20857142846, 82408.20857142846, 82408.20857142846, 82381.70142857132, 96879.16714285703, 80310.84285714275, 79917.47999999988, 79316.82285714275, 79316.82285714275, 79316.82285714275], "type": "scatter", "uid": "1dd773ee-25a6-4f7f-9ed4-be585075f6df"}], {"showlegend": true, "title": {"text": "Baseline Predictions i.e., 7-day moving average for last 14 days"}, "xaxis": {"rangeslider": {"visible": false}, "title": {"text": "Time Steps"}, "type": "date"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("6df22852-5f28-41b9-a461-ef8dd59f5c49"));});</script>

# %%
rmse = math.sqrt(mean_squared_error(df_out['Original'].values, df_out['Predicted'].values))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 56732.334

# %%
mape = mean_absolute_percentage_error(np.array(df_out['Predicted'].values),np.array(df_out['Original'].values))
print ('Test MAPE: %.3f' %mape)
# Out:
# Test MAPE: 60.004

# %%
err = (abs(sum(df_out['Predicted'].values) - sum(df_out['Original'].values)) / (sum(df_out['Original'].values))) *100
print ('Prediction Error: %.2f%%' %err)
# Out:
# Prediction Error: 10.78%

# %% [markdown]
# ### Statefull LSTM Model

# %%
# frame a sequence as a supervised learning problem
def timeseries_to_supervised(data, lag=1):
    df = pd.DataFrame(data)
    columns = [df.shift(i) for i in range(1, lag+1)]
    columns.append(df)
    df = pd.concat(columns, axis=1)
    df.fillna(0, inplace=True)
    return df

# %%
# scale train and test data to [-1, 1]
def scale(train, test):
	# fit scaler
	scaler = MinMaxScaler(feature_range=(-1, 1))
	scaler = scaler.fit(train)
	# transform train
	train_scaled = scaler.transform(train)
	# transform test
	test_scaled = scaler.transform(test)
	return scaler, train_scaled, test_scaled

# %%
# inverse scaling for a forecasted value
def invert_scale(scaler, X, value):
	new_row = [x for x in X] + [value]
	array = np.array(new_row)
	array = array.reshape(1, len(array))
	inverted = scaler.inverse_transform(array)
	return inverted[0, -1]

# %%
def fit_lstm(train, batch_size, nb_epoch, neurons, test = None, load_model = False):
    
    X, y = train[:, 0:-1], train[:, -1]
    X = X.reshape(X.shape[0], 1, X.shape[1])
    
    if test.any():
        X_test, y_test = test[:, 0:-1], test[:, -1]
        X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
                
    
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), 
                                stateful=True, return_sequences=True))
    model.add(tf.keras.layers.LSTM(neurons ,stateful=True))
    model.add(tf.keras.layers.Dense(1))
    model.compile('adam', loss='mse')
    
    if load_model:
        pass 
    
    c = [
          ModelCheckpoint(checkpoint_dir + model_filename, save_best_only=True,monitor='val_loss', mode='min', verbose=1, period=1),
          EarlyStopping(monitor='val_loss', min_delta=0, patience=200, verbose=1),
          ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=55, min_lr=0.0001, verbose=1)]
    
    
#     for i in range(nb_epoch):
#         print(i)
#         model.fit(X, y, epochs=1, batch_size=batch_size, verbose=2, shuffle=False, validation_data = (X_test, y_test) , callbacks = c)
#         model.reset_states()
        
    hist = model.fit(X, y, epochs=nb_epoch, batch_size=batch_size, verbose=2, shuffle=False, validation_data = (X_test, y_test) , callbacks = c) 
    
    return model, hist

# %%
# make a one-step forecast
def forecast_lstm(model, batch_size, X):
	X = X.reshape(1, 1, len(X))
	yhat = model.predict(X, batch_size=batch_size)
	return yhat[0,0]

# %%
# create a differenced series
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        #print(dataset[i])
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return pd.Series(diff)

# %%
def inverse_difference(history, yhat, interval=1):
  return yhat + history[-interval]

# %%
def plot_metrics(hist_name):
  
  plt.style.use('default')
  # plt.style.use('seaborn-deep')

  # sns.set(style="whitegrid")
  # sns.set_context("talk")

  fig, ax = plt.subplots(facecolor='w')
  fig.set_size_inches(fig.get_figwidth() * 2.0, fig.get_figheight() * 1.0)

  ax.plot(hist_name.history['loss'])
  ax.plot(hist_name.history['val_loss'])

  plt.xlabel('Epoch')
  plt.ylabel('MSE Loss')
  plt.title('Loss Over Time')
  plt.legend(['Train','Valid'])
  plt.show()
  
  return

# %% [markdown]
# **Data processing**

# %%
# transform data to be stationary
raw_values = df_raw['sale_amt'].values
diff_values = difference(raw_values, 1)

# %%
# transform data to be supervised learning
supervised = timeseries_to_supervised(diff_values, 1)
supervised_values = supervised.values

# %%
# split data into train and test-sets
train, test = supervised_values[:len(supervised_values)-14], supervised_values[len(supervised_values)-14:]

# %%
# transform the scale of the data
scaler, train_scaled, test_scaled = scale(train, test)

# %%
if train_model:
  # fit the model
  lstm_model, hist = fit_lstm(train_scaled, 1, 1200, 32, test_scaled)
# Out:
# W0516 17:23:43.131497 140058128934784 tf_logging.py:161] <tensorflow.python.keras.layers.recurrent.UnifiedLSTM object at 0x7f60ec86be10>: Note that this layer is not optimized for performance. Please use tf.keras.layers.CuDNNLSTM for better performance on GPU.
# W0516 17:23:43.226477 140058128934784 tf_logging.py:161] <tensorflow.python.keras.layers.recurrent.UnifiedLSTM object at 0x7f60ec86b908>: Note that this layer is not optimized for performance. Please use tf.keras.layers.CuDNNLSTM for better performance on GPU.
# Train on 634 samples, validate on 14 samples
# Epoch 1/1200
#
# Epoch 00001: val_loss improved from inf to 0.24601, saving model to /content/model1_eu.hdf5
# 634/634 - 3s - loss: 0.0805 - val_loss: 0.2460
# Epoch 2/1200
#
# Epoch 00002: val_loss did not improve from 0.24601
# 634/634 - 2s - loss: 0.0625 - val_loss: 13.6930
# Epoch 3/1200
#
# Epoch 00003: val_loss improved from 0.24601 to 0.13905, saving model to /content/model1_eu.hdf5
# 634/634 - 2s - loss: 0.6925 - val_loss: 0.1390
# Epoch 4/1200
#
# Epoch 00004: val_loss did not improve from 0.13905
# 634/634 - 2s - loss: 0.0667 - val_loss: 0.1634
# Epoch 5/1200
#
# Epoch 00005: val_loss did not improve from 0.13905
# 634/634 - 2s - loss: 0.0768 - val_loss: 0.1964
# Epoch 6/1200
#
# Epoch 00006: val_loss did not improve from 0.13905
# 634/634 - 2s - loss: 0.0777 - val_loss: 0.1556
# Epoch 7/1200
#
# Epoch 00007: val_loss improved from 0.13905 to 0.11969, saving model to /content/model1_eu.hdf5
# 634/634 - 2s - loss: 0.0745 - val_loss: 0.1197
# Epoch 8/1200
#
# Epoch 00008: val_loss improved from 0.11969 to 0.10992, saving model to /content/model1_eu.hdf5
# 634/634 - 2s - loss: 0.0736 - val_loss: 0.1099
# Epoch 9/1200
#
# Epoch 00009: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0721 - val_loss: 0.1221
# Epoch 10/1200
#
# Epoch 00010: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0707 - val_loss: 0.1273
# Epoch 11/1200
#
# Epoch 00011: val_loss did not improve from 0.10992
# 634/634 - 3s - loss: 0.0710 - val_loss: 0.2421
# Epoch 12/1200
#
# Epoch 00012: val_loss did not improve from 0.10992
# 634/634 - 3s - loss: 0.0657 - val_loss: 0.1345
# Epoch 13/1200
#
# Epoch 00013: val_loss did not improve from 0.10992
# 634/634 - 3s - loss: 0.0618 - val_loss: 0.3175
# Epoch 14/1200
#
# Epoch 00014: val_loss did not improve from 0.10992
# 634/634 - 3s - loss: 0.0652 - val_loss: 0.2849
# Epoch 15/1200
#
# Epoch 00015: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0553 - val_loss: 0.2464
# Epoch 16/1200
#
# Epoch 00016: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0593 - val_loss: 0.2842
# Epoch 17/1200
#
# Epoch 00017: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0527 - val_loss: 0.3875
# Epoch 18/1200
#
# Epoch 00018: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0579 - val_loss: 0.3884
# Epoch 19/1200
#
# Epoch 00019: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0489 - val_loss: 0.4790
# Epoch 20/1200
#
# Epoch 00020: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0436 - val_loss: 0.2131
# Epoch 21/1200
#
# Epoch 00021: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0368 - val_loss: 0.1417
# Epoch 22/1200
#
# Epoch 00022: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0345 - val_loss: 0.3243
# Epoch 23/1200
#
# Epoch 00023: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0301 - val_loss: 0.3032
# Epoch 24/1200
#
# Epoch 00024: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0329 - val_loss: 0.2366
# Epoch 25/1200
#
# Epoch 00025: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0273 - val_loss: 0.2533
# Epoch 26/1200
#
# Epoch 00026: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0253 - val_loss: 0.2702
# Epoch 27/1200
#
# Epoch 00027: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0266 - val_loss: 0.2722
# Epoch 28/1200
#
# Epoch 00028: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0277 - val_loss: 0.2707
# Epoch 29/1200
#
# Epoch 00029: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0259 - val_loss: 0.1477
# Epoch 30/1200
#
# Epoch 00030: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0246 - val_loss: 0.3853
# Epoch 31/1200
#
# Epoch 00031: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0235 - val_loss: 0.3274
# Epoch 32/1200
#
# Epoch 00032: val_loss did not improve from 0.10992
# 634/634 - 2s - loss: 0.0218 - val_loss: 0.2518
# Epoch 33/1200
#
# Epoch 00033: val_loss improved from 0.10992 to 0.06731, saving model to /content/model1_eu.hdf5
# 634/634 - 2s - loss: 0.0228 - val_loss: 0.0673
# Epoch 34/1200
#
# Epoch 00034: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0242 - val_loss: 0.1757
# Epoch 35/1200
#
# Epoch 00035: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0227 - val_loss: 0.3004
# Epoch 36/1200
#
# Epoch 00036: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0211 - val_loss: 0.1315
# Epoch 37/1200
#
# Epoch 00037: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0210 - val_loss: 0.1716
# Epoch 38/1200
#
# Epoch 00038: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0221 - val_loss: 0.2486
# Epoch 39/1200
#
# Epoch 00039: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0187 - val_loss: 0.2593
# Epoch 40/1200
#
# Epoch 00040: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0178 - val_loss: 0.2706
# Epoch 41/1200
#
# Epoch 00041: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0179 - val_loss: 0.2316
# Epoch 42/1200
#
# Epoch 00042: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0184 - val_loss: 0.2910
# Epoch 43/1200
#
# Epoch 00043: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0164 - val_loss: 0.1804
# Epoch 44/1200
#
# Epoch 00044: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0171 - val_loss: 0.1882
# Epoch 45/1200
#
# Epoch 00045: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0172 - val_loss: 0.3077
# Epoch 46/1200
#
# Epoch 00046: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0176 - val_loss: 0.2576
# Epoch 47/1200
#
# Epoch 00047: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0172 - val_loss: 0.4011
# Epoch 48/1200
#
# Epoch 00048: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0163 - val_loss: 0.2296
# Epoch 49/1200
#
# Epoch 00049: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0172 - val_loss: 0.3408
# Epoch 50/1200
#
# Epoch 00050: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0167 - val_loss: 0.3167
# Epoch 51/1200
#
# Epoch 00051: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0180 - val_loss: 0.2739
# Epoch 52/1200
#
# Epoch 00052: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0169 - val_loss: 0.1942
# Epoch 53/1200
#
# Epoch 00053: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0166 - val_loss: 0.2168
# Epoch 54/1200
#
# Epoch 00054: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0174 - val_loss: 0.2925
# Epoch 55/1200
#
# Epoch 00055: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0157 - val_loss: 0.1584
# Epoch 56/1200
#
# Epoch 00056: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0171 - val_loss: 0.3031
# Epoch 57/1200
#
# Epoch 00057: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0159 - val_loss: 0.2454
# Epoch 58/1200
#
# Epoch 00058: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0167 - val_loss: 0.2934
# Epoch 59/1200
#
# Epoch 00059: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0162 - val_loss: 0.3510
# Epoch 60/1200
#
# Epoch 00060: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0150 - val_loss: 0.2025
# Epoch 61/1200
#
# Epoch 00061: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0170 - val_loss: 0.3123
# Epoch 62/1200
#
# Epoch 00062: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0152 - val_loss: 0.1667
# Epoch 63/1200
#
# Epoch 00063: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0163 - val_loss: 0.3113
# Epoch 64/1200
#
# Epoch 00064: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0148 - val_loss: 0.1927
# Epoch 65/1200
#
# Epoch 00065: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0148 - val_loss: 0.0936
# Epoch 66/1200
#
# Epoch 00066: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0142 - val_loss: 0.2898
# Epoch 67/1200
#
# Epoch 00067: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0154 - val_loss: 0.2736
# Epoch 68/1200
#
# Epoch 00068: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0145 - val_loss: 0.2440
# Epoch 69/1200
#
# Epoch 00069: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0168 - val_loss: 0.1324
# Epoch 70/1200
#
# Epoch 00070: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0142 - val_loss: 0.2639
# Epoch 71/1200
#
# Epoch 00071: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0135 - val_loss: 0.2322
# Epoch 72/1200
#
# Epoch 00072: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0152 - val_loss: 0.2425
# Epoch 73/1200
#
# Epoch 00073: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0141 - val_loss: 0.1801
# Epoch 74/1200
#
# Epoch 00074: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0153 - val_loss: 0.2568
# Epoch 75/1200
#
# Epoch 00075: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0141 - val_loss: 0.1955
# Epoch 76/1200
#
# Epoch 00076: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0139 - val_loss: 0.2581
# Epoch 77/1200
#
# Epoch 00077: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0147 - val_loss: 0.2495
# Epoch 78/1200
#
# Epoch 00078: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0143 - val_loss: 0.1875
# Epoch 79/1200
#
# Epoch 00079: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0149 - val_loss: 0.2776
# Epoch 80/1200
#
# Epoch 00080: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0140 - val_loss: 0.1685
# Epoch 81/1200
#
# Epoch 00081: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0136 - val_loss: 0.1826
# Epoch 82/1200
#
# Epoch 00082: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0143 - val_loss: 0.1195
# Epoch 83/1200
#
# Epoch 00083: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0150 - val_loss: 0.1463
# Epoch 84/1200
#
# Epoch 00084: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0146 - val_loss: 0.2380
# Epoch 85/1200
#
# Epoch 00085: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0168 - val_loss: 0.2547
# Epoch 86/1200
#
# Epoch 00086: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0137 - val_loss: 0.2329
# Epoch 87/1200
#
# Epoch 00087: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0133 - val_loss: 0.1417
# Epoch 88/1200
#
# Epoch 00088: val_loss did not improve from 0.06731
#
# Epoch 00088: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 634/634 - 2s - loss: 0.0149 - val_loss: 0.1300
# Epoch 89/1200
#
# Epoch 00089: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0159 - val_loss: 0.2662
# Epoch 90/1200
#
# Epoch 00090: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0134 - val_loss: 0.2837
# Epoch 91/1200
#
# Epoch 00091: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0170 - val_loss: 0.2641
# Epoch 92/1200
#
# Epoch 00092: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0131 - val_loss: 0.2135
# Epoch 93/1200
#
# Epoch 00093: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0129 - val_loss: 0.1904
# Epoch 94/1200
#
# Epoch 00094: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0135 - val_loss: 0.0913
# Epoch 95/1200
#
# Epoch 00095: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0132 - val_loss: 0.1326
# Epoch 96/1200
#
# Epoch 00096: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0134 - val_loss: 0.1563
# Epoch 97/1200
#
# Epoch 00097: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0126 - val_loss: 0.2639
# Epoch 98/1200
#
# Epoch 00098: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0137 - val_loss: 0.1791
# Epoch 99/1200
#
# Epoch 00099: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0128 - val_loss: 0.2294
# Epoch 100/1200
#
# Epoch 00100: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0129 - val_loss: 0.1676
# Epoch 101/1200
#
# Epoch 00101: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0125 - val_loss: 0.2925
# Epoch 102/1200
#
# Epoch 00102: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0124 - val_loss: 0.2804
# Epoch 103/1200
#
# Epoch 00103: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0122 - val_loss: 0.2540
# Epoch 104/1200
#
# Epoch 00104: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0125 - val_loss: 0.2556
# Epoch 105/1200
#
# Epoch 00105: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0125 - val_loss: 0.2619
# Epoch 106/1200
#
# Epoch 00106: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0123 - val_loss: 0.1416
# Epoch 107/1200
#
# Epoch 00107: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0123 - val_loss: 0.2565
# Epoch 108/1200
#
# Epoch 00108: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0123 - val_loss: 0.3082
# Epoch 109/1200
#
# Epoch 00109: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0124 - val_loss: 0.3301
# Epoch 110/1200
#
# Epoch 00110: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0113 - val_loss: 0.3592
# Epoch 111/1200
#
# Epoch 00111: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0114 - val_loss: 0.3191
# Epoch 112/1200
#
# Epoch 00112: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0123 - val_loss: 0.2633
# Epoch 113/1200
#
# Epoch 00113: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0136 - val_loss: 0.2146
# Epoch 114/1200
#
# Epoch 00114: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0120 - val_loss: 0.2275
# Epoch 115/1200
#
# Epoch 00115: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0120 - val_loss: 0.1412
# Epoch 116/1200
#
# Epoch 00116: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0122 - val_loss: 0.2382
# Epoch 117/1200
#
# Epoch 00117: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0118 - val_loss: 0.1993
# Epoch 118/1200
#
# Epoch 00118: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0121 - val_loss: 0.2137
# Epoch 119/1200
#
# Epoch 00119: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0113 - val_loss: 0.4109
# Epoch 120/1200
#
# Epoch 00120: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0118 - val_loss: 0.2832
# Epoch 121/1200
#
# Epoch 00121: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0122 - val_loss: 0.2272
# Epoch 122/1200
#
# Epoch 00122: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0114 - val_loss: 0.2988
# Epoch 123/1200
#
# Epoch 00123: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0130 - val_loss: 0.2970
# Epoch 124/1200
#
# Epoch 00124: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0113 - val_loss: 0.2260
# Epoch 125/1200
#
# Epoch 00125: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0122 - val_loss: 0.3112
# Epoch 126/1200
#
# Epoch 00126: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0128 - val_loss: 0.3236
# Epoch 127/1200
#
# Epoch 00127: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0124 - val_loss: 0.2863
# Epoch 128/1200
#
# Epoch 00128: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0122 - val_loss: 0.2263
# Epoch 129/1200
#
# Epoch 00129: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0123 - val_loss: 0.3095
# Epoch 130/1200
#
# Epoch 00130: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0125 - val_loss: 0.2594
# Epoch 131/1200
#
# Epoch 00131: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0120 - val_loss: 0.2923
# Epoch 132/1200
#
# Epoch 00132: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0135 - val_loss: 0.2696
# Epoch 133/1200
#
# Epoch 00133: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0125 - val_loss: 0.2479
# Epoch 134/1200
#
# Epoch 00134: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0124 - val_loss: 0.3042
# Epoch 135/1200
#
# Epoch 00135: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0108 - val_loss: 0.2642
# Epoch 136/1200
#
# Epoch 00136: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0116 - val_loss: 0.2186
# Epoch 137/1200
#
# Epoch 00137: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0136 - val_loss: 0.3555
# Epoch 138/1200
#
# Epoch 00138: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0122 - val_loss: 0.2661
# Epoch 139/1200
#
# Epoch 00139: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0117 - val_loss: 0.2020
# Epoch 140/1200
#
# Epoch 00140: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0126 - val_loss: 0.3631
# Epoch 141/1200
#
# Epoch 00141: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0124 - val_loss: 0.2818
# Epoch 142/1200
#
# Epoch 00142: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0118 - val_loss: 0.1645
# Epoch 143/1200
#
# Epoch 00143: val_loss did not improve from 0.06731
#
# Epoch 00143: ReduceLROnPlateau reducing learning rate to 0.0001.
# 634/634 - 3s - loss: 0.0130 - val_loss: 0.4096
# Epoch 144/1200
#
# Epoch 00144: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0117 - val_loss: 0.2367
# Epoch 145/1200
#
# Epoch 00145: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0120 - val_loss: 0.3800
# Epoch 146/1200
#
# Epoch 00146: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0131 - val_loss: 0.3379
# Epoch 147/1200
#
# Epoch 00147: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0129 - val_loss: 0.1535
# Epoch 148/1200
#
# Epoch 00148: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0129 - val_loss: 0.2977
# Epoch 149/1200
#
# Epoch 00149: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0115 - val_loss: 0.2379
# Epoch 150/1200
#
# Epoch 00150: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0131 - val_loss: 0.3226
# Epoch 151/1200
#
# Epoch 00151: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0122 - val_loss: 0.2753
# Epoch 152/1200
#
# Epoch 00152: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0116 - val_loss: 0.2700
# Epoch 153/1200
#
# Epoch 00153: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0131 - val_loss: 0.3269
# Epoch 154/1200
#
# Epoch 00154: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0128 - val_loss: 0.1069
# Epoch 155/1200
#
# Epoch 00155: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0117 - val_loss: 0.2426
# Epoch 156/1200
#
# Epoch 00156: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0114 - val_loss: 0.3053
# Epoch 157/1200
#
# Epoch 00157: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0113 - val_loss: 0.2175
# Epoch 158/1200
#
# Epoch 00158: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0124 - val_loss: 0.2632
# Epoch 159/1200
#
# Epoch 00159: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0132 - val_loss: 0.2799
# Epoch 160/1200
#
# Epoch 00160: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0117 - val_loss: 0.2386
# Epoch 161/1200
#
# Epoch 00161: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0139 - val_loss: 0.2759
# Epoch 162/1200
#
# Epoch 00162: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0127 - val_loss: 0.2047
# Epoch 163/1200
#
# Epoch 00163: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0132 - val_loss: 0.2613
# Epoch 164/1200
#
# Epoch 00164: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0133 - val_loss: 0.2763
# Epoch 165/1200
#
# Epoch 00165: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0119 - val_loss: 0.2209
# Epoch 166/1200
#
# Epoch 00166: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0118 - val_loss: 0.2060
# Epoch 167/1200
#
# Epoch 00167: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0134 - val_loss: 0.2484
# Epoch 168/1200
#
# Epoch 00168: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0135 - val_loss: 0.2457
# Epoch 169/1200
#
# Epoch 00169: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0126 - val_loss: 0.2841
# Epoch 170/1200
#
# Epoch 00170: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0152 - val_loss: 0.3427
# Epoch 171/1200
#
# Epoch 00171: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0131 - val_loss: 0.1603
# Epoch 172/1200
#
# Epoch 00172: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0139 - val_loss: 0.2143
# Epoch 173/1200
#
# Epoch 00173: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0131 - val_loss: 0.2565
# Epoch 174/1200
#
# Epoch 00174: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0114 - val_loss: 0.2884
# Epoch 175/1200
#
# Epoch 00175: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0134 - val_loss: 0.2582
# Epoch 176/1200
#
# Epoch 00176: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0126 - val_loss: 0.2443
# Epoch 177/1200
#
# Epoch 00177: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0119 - val_loss: 0.4000
# Epoch 178/1200
#
# Epoch 00178: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0127 - val_loss: 0.1961
# Epoch 179/1200
#
# Epoch 00179: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0125 - val_loss: 0.3610
# Epoch 180/1200
#
# Epoch 00180: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0129 - val_loss: 0.1458
# Epoch 181/1200
#
# Epoch 00181: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0130 - val_loss: 0.3189
# Epoch 182/1200
#
# Epoch 00182: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0115 - val_loss: 0.3005
# Epoch 183/1200
#
# Epoch 00183: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0117 - val_loss: 0.1776
# Epoch 184/1200
#
# Epoch 00184: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0137 - val_loss: 0.4726
# Epoch 185/1200
#
# Epoch 00185: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0121 - val_loss: 0.1652
# Epoch 186/1200
#
# Epoch 00186: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0133 - val_loss: 0.1881
# Epoch 187/1200
#
# Epoch 00187: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0122 - val_loss: 0.2297
# Epoch 188/1200
#
# Epoch 00188: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0130 - val_loss: 0.1641
# Epoch 189/1200
#
# Epoch 00189: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0131 - val_loss: 0.4266
# Epoch 190/1200
#
# Epoch 00190: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0125 - val_loss: 0.3590
# Epoch 191/1200
#
# Epoch 00191: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0114 - val_loss: 0.3434
# Epoch 192/1200
#
# Epoch 00192: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0118 - val_loss: 0.2663
# Epoch 193/1200
#
# Epoch 00193: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0129 - val_loss: 0.2719
# Epoch 194/1200
#
# Epoch 00194: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0129 - val_loss: 0.2285
# Epoch 195/1200
#
# Epoch 00195: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0135 - val_loss: 0.2585
# Epoch 196/1200
#
# Epoch 00196: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0140 - val_loss: 0.3846
# Epoch 197/1200
#
# Epoch 00197: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0113 - val_loss: 0.2662
# Epoch 198/1200
#
# Epoch 00198: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0124 - val_loss: 0.0992
# Epoch 199/1200
#
# Epoch 00199: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0116 - val_loss: 0.1757
# Epoch 200/1200
#
# Epoch 00200: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0116 - val_loss: 0.3192
# Epoch 201/1200
#
# Epoch 00201: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0112 - val_loss: 0.3065
# Epoch 202/1200
#
# Epoch 00202: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0117 - val_loss: 0.3147
# Epoch 203/1200
#
# Epoch 00203: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0117 - val_loss: 0.2781
# Epoch 204/1200
#
# Epoch 00204: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0123 - val_loss: 0.3507
# Epoch 205/1200
#
# Epoch 00205: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0129 - val_loss: 0.2852
# Epoch 206/1200
#
# Epoch 00206: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0122 - val_loss: 0.1483
# Epoch 207/1200
#
# Epoch 00207: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0133 - val_loss: 0.2443
# Epoch 208/1200
#
# Epoch 00208: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0136 - val_loss: 0.3322
# Epoch 209/1200
#
# Epoch 00209: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0136 - val_loss: 0.1955
# Epoch 210/1200
#
# Epoch 00210: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0128 - val_loss: 0.1773
# Epoch 211/1200
#
# Epoch 00211: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0110 - val_loss: 0.2241
# Epoch 212/1200
#
# Epoch 00212: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0118 - val_loss: 0.1824
# Epoch 213/1200
#
# Epoch 00213: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0113 - val_loss: 0.3036
# Epoch 214/1200
#
# Epoch 00214: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0117 - val_loss: 0.3089
# Epoch 215/1200
#
# Epoch 00215: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0121 - val_loss: 0.2848
# Epoch 216/1200
#
# Epoch 00216: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0123 - val_loss: 0.2080
# Epoch 217/1200
#
# Epoch 00217: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0119 - val_loss: 0.2948
# Epoch 218/1200
#
# Epoch 00218: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0108 - val_loss: 0.1968
# Epoch 219/1200
#
# Epoch 00219: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0142 - val_loss: 0.3194
# Epoch 220/1200
#
# Epoch 00220: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0109 - val_loss: 0.3261
# Epoch 221/1200
#
# Epoch 00221: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0111 - val_loss: 0.2728
# Epoch 222/1200
#
# Epoch 00222: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0145 - val_loss: 0.3105
# Epoch 223/1200
#
# Epoch 00223: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0154 - val_loss: 0.2039
# Epoch 224/1200
#
# Epoch 00224: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0148 - val_loss: 0.2565
# Epoch 225/1200
#
# Epoch 00225: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0120 - val_loss: 0.2219
# Epoch 226/1200
#
# Epoch 00226: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0121 - val_loss: 0.2671
# Epoch 227/1200
#
# Epoch 00227: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0113 - val_loss: 0.2899
# Epoch 228/1200
#
# Epoch 00228: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0103 - val_loss: 0.2801
# Epoch 229/1200
#
# Epoch 00229: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0120 - val_loss: 0.2768
# Epoch 230/1200
#
# Epoch 00230: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0116 - val_loss: 0.2998
# Epoch 231/1200
#
# Epoch 00231: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0124 - val_loss: 0.1968
# Epoch 232/1200
#
# Epoch 00232: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0138 - val_loss: 0.2933
# Epoch 233/1200
#
# Epoch 00233: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0122 - val_loss: 0.2164
# Epoch 234/1200
#
# Epoch 00234: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0112 - val_loss: 0.2488
# Epoch 235/1200
#
# Epoch 00235: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0131 - val_loss: 0.3507
# Epoch 236/1200
#
# Epoch 00236: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0114 - val_loss: 0.1315
# Epoch 237/1200
#
# Epoch 00237: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0106 - val_loss: 0.2024
# Epoch 238/1200
#
# Epoch 00238: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0143 - val_loss: 0.2224
# Epoch 239/1200
#
# Epoch 00239: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0124 - val_loss: 0.3153
# Epoch 240/1200
#
# Epoch 00240: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0103 - val_loss: 0.1841
# Epoch 241/1200
#
# Epoch 00241: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0124 - val_loss: 0.2825
# Epoch 242/1200
#
# Epoch 00242: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0124 - val_loss: 0.2174
# Epoch 243/1200
#
# Epoch 00243: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0109 - val_loss: 0.3249
# Epoch 244/1200
#
# Epoch 00244: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0124 - val_loss: 0.2113
# Epoch 245/1200
#
# Epoch 00245: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0119 - val_loss: 0.3926
# Epoch 246/1200
#
# Epoch 00246: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0126 - val_loss: 0.1584
# Epoch 247/1200
#
# Epoch 00247: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0121 - val_loss: 0.2200
# Epoch 248/1200
#
# Epoch 00248: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0121 - val_loss: 0.2253
# Epoch 249/1200
#
# Epoch 00249: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0141 - val_loss: 0.1858
# Epoch 250/1200
#
# Epoch 00250: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0106 - val_loss: 0.1931
# Epoch 251/1200
#
# Epoch 00251: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0114 - val_loss: 0.1868
# Epoch 252/1200
#
# Epoch 00252: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0114 - val_loss: 0.1055
# Epoch 253/1200
#
# Epoch 00253: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0112 - val_loss: 0.2371
# Epoch 254/1200
#
# Epoch 00254: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0143 - val_loss: 0.2396
# Epoch 255/1200
#
# Epoch 00255: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0101 - val_loss: 0.1652
# Epoch 256/1200
#
# Epoch 00256: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0113 - val_loss: 0.2288
# Epoch 257/1200
#
# Epoch 00257: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0102 - val_loss: 0.1541
# Epoch 258/1200
#
# Epoch 00258: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0099 - val_loss: 0.1902
# Epoch 259/1200
#
# Epoch 00259: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0109 - val_loss: 0.2548
# Epoch 260/1200
#
# Epoch 00260: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0127 - val_loss: 0.2903
# Epoch 261/1200
#
# Epoch 00261: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0101 - val_loss: 0.2589
# Epoch 262/1200
#
# Epoch 00262: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0142 - val_loss: 0.3438
# Epoch 263/1200
#
# Epoch 00263: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0107 - val_loss: 0.1994
# Epoch 264/1200
#
# Epoch 00264: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0131 - val_loss: 0.1808
# Epoch 265/1200
#
# Epoch 00265: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0109 - val_loss: 0.1232
# Epoch 266/1200
#
# Epoch 00266: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0104 - val_loss: 0.3461
# Epoch 267/1200
#
# Epoch 00267: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0118 - val_loss: 0.1455
# Epoch 268/1200
#
# Epoch 00268: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0108 - val_loss: 0.1660
# Epoch 269/1200
#
# Epoch 00269: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0104 - val_loss: 0.2646
# Epoch 270/1200
#
# Epoch 00270: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0113 - val_loss: 0.2200
# Epoch 271/1200
#
# Epoch 00271: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0100 - val_loss: 0.2752
# Epoch 272/1200
#
# Epoch 00272: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0104 - val_loss: 0.4405
# Epoch 273/1200
#
# Epoch 00273: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0110 - val_loss: 0.2105
# Epoch 274/1200
#
# Epoch 00274: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0101 - val_loss: 0.2241
# Epoch 275/1200
#
# Epoch 00275: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0120 - val_loss: 0.1180
# Epoch 276/1200
#
# Epoch 00276: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0109 - val_loss: 0.1945
# Epoch 277/1200
#
# Epoch 00277: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0115 - val_loss: 0.4135
# Epoch 278/1200
#
# Epoch 00278: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0106 - val_loss: 0.2343
# Epoch 279/1200
#
# Epoch 00279: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0132 - val_loss: 0.2028
# Epoch 280/1200
#
# Epoch 00280: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0107 - val_loss: 0.1939
# Epoch 281/1200
#
# Epoch 00281: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0109 - val_loss: 0.3715
# Epoch 282/1200
#
# Epoch 00282: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0096 - val_loss: 0.2529
# Epoch 283/1200
#
# Epoch 00283: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0139 - val_loss: 0.2315
# Epoch 284/1200
#
# Epoch 00284: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0105 - val_loss: 0.1209
# Epoch 285/1200
#
# Epoch 00285: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0114 - val_loss: 0.1798
# Epoch 286/1200
#
# Epoch 00286: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0109 - val_loss: 0.3033
# Epoch 287/1200
#
# Epoch 00287: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0099 - val_loss: 0.1856
# Epoch 288/1200
#
# Epoch 00288: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0114 - val_loss: 0.2380
# Epoch 289/1200
#
# Epoch 00289: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0105 - val_loss: 0.2856
# Epoch 290/1200
#
# Epoch 00290: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0135 - val_loss: 0.2428
# Epoch 291/1200
#
# Epoch 00291: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0114 - val_loss: 0.2662
# Epoch 292/1200
#
# Epoch 00292: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0100 - val_loss: 0.3708
# Epoch 293/1200
#
# Epoch 00293: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0103 - val_loss: 0.2888
# Epoch 294/1200
#
# Epoch 00294: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0096 - val_loss: 0.3183
# Epoch 295/1200
#
# Epoch 00295: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0108 - val_loss: 0.2762
# Epoch 296/1200
#
# Epoch 00296: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0105 - val_loss: 0.2306
# Epoch 297/1200
#
# Epoch 00297: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0113 - val_loss: 0.2680
# Epoch 298/1200
#
# Epoch 00298: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0110 - val_loss: 0.3017
# Epoch 299/1200
#
# Epoch 00299: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0104 - val_loss: 0.2588
# Epoch 300/1200
#
# Epoch 00300: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0133 - val_loss: 0.3344
# Epoch 301/1200
#
# Epoch 00301: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0103 - val_loss: 0.1869
# Epoch 302/1200
#
# Epoch 00302: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0104 - val_loss: 0.3265
# Epoch 303/1200
#
# Epoch 00303: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0109 - val_loss: 0.2427
# Epoch 304/1200
#
# Epoch 00304: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0096 - val_loss: 0.4704
# Epoch 305/1200
#
# Epoch 00305: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0105 - val_loss: 0.2122
# Epoch 306/1200
#
# Epoch 00306: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0103 - val_loss: 0.2551
# Epoch 307/1200
#
# Epoch 00307: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0098 - val_loss: 0.1643
# Epoch 308/1200
#
# Epoch 00308: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0126 - val_loss: 0.2178
# Epoch 309/1200
#
# Epoch 00309: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0100 - val_loss: 0.0977
# Epoch 310/1200
#
# Epoch 00310: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0102 - val_loss: 0.3052
# Epoch 311/1200
#
# Epoch 00311: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0096 - val_loss: 0.1951
# Epoch 312/1200
#
# Epoch 00312: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0108 - val_loss: 0.1886
# Epoch 313/1200
#
# Epoch 00313: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0097 - val_loss: 0.1688
# Epoch 314/1200
#
# Epoch 00314: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0112 - val_loss: 0.2645
# Epoch 315/1200
#
# Epoch 00315: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0097 - val_loss: 0.2184
# Epoch 316/1200
#
# Epoch 00316: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0108 - val_loss: 0.1941
# Epoch 317/1200
#
# Epoch 00317: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0110 - val_loss: 0.2902
# Epoch 318/1200
#
# Epoch 00318: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0105 - val_loss: 0.2355
# Epoch 319/1200
#
# Epoch 00319: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0102 - val_loss: 0.3881
# Epoch 320/1200
#
# Epoch 00320: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0098 - val_loss: 0.2083
# Epoch 321/1200
#
# Epoch 00321: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0102 - val_loss: 0.2282
# Epoch 322/1200
#
# Epoch 00322: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0099 - val_loss: 0.2566
# Epoch 323/1200
#
# Epoch 00323: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0105 - val_loss: 0.2818
# Epoch 324/1200
#
# Epoch 00324: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0100 - val_loss: 0.1787
# Epoch 325/1200
#
# Epoch 00325: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0115 - val_loss: 0.1382
# Epoch 326/1200
#
# Epoch 00326: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0099 - val_loss: 0.4858
# Epoch 327/1200
#
# Epoch 00327: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0107 - val_loss: 0.2840
# Epoch 328/1200
#
# Epoch 00328: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0104 - val_loss: 0.2441
# Epoch 329/1200
#
# Epoch 00329: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0119 - val_loss: 0.3773
# Epoch 330/1200
#
# Epoch 00330: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0099 - val_loss: 0.1138
# Epoch 331/1200
#
# Epoch 00331: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0126 - val_loss: 0.1589
# Epoch 332/1200
#
# Epoch 00332: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0102 - val_loss: 0.1941
# Epoch 333/1200
#
# Epoch 00333: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0104 - val_loss: 0.2999
# Epoch 334/1200
#
# Epoch 00334: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0093 - val_loss: 0.4289
# Epoch 335/1200
#
# Epoch 00335: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0102 - val_loss: 0.3292
# Epoch 336/1200
#
# Epoch 00336: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0101 - val_loss: 0.2686
# Epoch 337/1200
#
# Epoch 00337: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0101 - val_loss: 0.1825
# Epoch 338/1200
#
# Epoch 00338: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0110 - val_loss: 0.2139
# Epoch 339/1200
#
# Epoch 00339: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0110 - val_loss: 0.4113
# Epoch 340/1200
#
# Epoch 00340: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0103 - val_loss: 0.3336
# Epoch 341/1200
#
# Epoch 00341: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0102 - val_loss: 0.2019
# Epoch 342/1200
#
# Epoch 00342: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0100 - val_loss: 0.3736
# Epoch 343/1200
#
# Epoch 00343: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0093 - val_loss: 0.2223
# Epoch 344/1200
#
# Epoch 00344: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0104 - val_loss: 0.2419
# Epoch 345/1200
#
# Epoch 00345: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0103 - val_loss: 0.4102
# Epoch 346/1200
#
# Epoch 00346: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0107 - val_loss: 0.1183
# Epoch 347/1200
#
# Epoch 00347: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0101 - val_loss: 0.4185
# Epoch 348/1200
#
# Epoch 00348: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0104 - val_loss: 0.3118
# Epoch 349/1200
#
# Epoch 00349: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0107 - val_loss: 0.2665
# Epoch 350/1200
#
# Epoch 00350: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0090 - val_loss: 0.1957
# Epoch 351/1200
#
# Epoch 00351: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0092 - val_loss: 0.1907
# Epoch 352/1200
#
# Epoch 00352: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0108 - val_loss: 0.2585
# Epoch 353/1200
#
# Epoch 00353: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0094 - val_loss: 0.1585
# Epoch 354/1200
#
# Epoch 00354: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0102 - val_loss: 0.2146
# Epoch 355/1200
#
# Epoch 00355: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0106 - val_loss: 0.4075
# Epoch 356/1200
#
# Epoch 00356: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0096 - val_loss: 0.2426
# Epoch 357/1200
#
# Epoch 00357: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0137 - val_loss: 0.2466
# Epoch 358/1200
#
# Epoch 00358: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0107 - val_loss: 0.3179
# Epoch 359/1200
#
# Epoch 00359: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0098 - val_loss: 0.3519
# Epoch 360/1200
#
# Epoch 00360: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0093 - val_loss: 0.2224
# Epoch 361/1200
#
# Epoch 00361: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0102 - val_loss: 0.2453
# Epoch 362/1200
#
# Epoch 00362: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0101 - val_loss: 0.1270
# Epoch 363/1200
#
# Epoch 00363: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0101 - val_loss: 0.2216
# Epoch 364/1200
#
# Epoch 00364: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0117 - val_loss: 0.2174
# Epoch 365/1200
#
# Epoch 00365: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0099 - val_loss: 0.2152
# Epoch 366/1200
#
# Epoch 00366: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0121 - val_loss: 0.3339
# Epoch 367/1200
#
# Epoch 00367: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0097 - val_loss: 0.1498
# Epoch 368/1200
#
# Epoch 00368: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0100 - val_loss: 0.1629
# Epoch 369/1200
#
# Epoch 00369: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0104 - val_loss: 0.2908
# Epoch 370/1200
#
# Epoch 00370: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0125 - val_loss: 0.2673
# Epoch 371/1200
#
# Epoch 00371: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0129 - val_loss: 0.1289
# Epoch 372/1200
#
# Epoch 00372: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0103 - val_loss: 0.3732
# Epoch 373/1200
#
# Epoch 00373: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0105 - val_loss: 0.2229
# Epoch 374/1200
#
# Epoch 00374: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0093 - val_loss: 0.2797
# Epoch 375/1200
#
# Epoch 00375: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0099 - val_loss: 0.2491
# Epoch 376/1200
#
# Epoch 00376: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0093 - val_loss: 0.3310
# Epoch 377/1200
#
# Epoch 00377: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0095 - val_loss: 0.3118
# Epoch 378/1200
#
# Epoch 00378: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0101 - val_loss: 0.2514
# Epoch 379/1200
#
# Epoch 00379: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0108 - val_loss: 0.2223
# Epoch 380/1200
#
# Epoch 00380: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0098 - val_loss: 0.2857
# Epoch 381/1200
#
# Epoch 00381: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0108 - val_loss: 0.2627
# Epoch 382/1200
#
# Epoch 00382: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0093 - val_loss: 0.1665
# Epoch 383/1200
#
# Epoch 00383: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0095 - val_loss: 0.2473
# Epoch 384/1200
#
# Epoch 00384: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0091 - val_loss: 0.2871
# Epoch 385/1200
#
# Epoch 00385: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0095 - val_loss: 0.2079
# Epoch 386/1200
#
# Epoch 00386: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0098 - val_loss: 0.1619
# Epoch 387/1200
#
# Epoch 00387: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0102 - val_loss: 0.3387
# Epoch 388/1200
#
# Epoch 00388: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0110 - val_loss: 0.2520
# Epoch 389/1200
#
# Epoch 00389: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0096 - val_loss: 0.2814
# Epoch 390/1200
#
# Epoch 00390: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0107 - val_loss: 0.2826
# Epoch 391/1200
#
# Epoch 00391: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0101 - val_loss: 0.1993
# Epoch 392/1200
#
# Epoch 00392: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0093 - val_loss: 0.1265
# Epoch 393/1200
#
# Epoch 00393: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0128 - val_loss: 0.4326
# Epoch 394/1200
#
# Epoch 00394: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0093 - val_loss: 0.3075
# Epoch 395/1200
#
# Epoch 00395: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0094 - val_loss: 0.3435
# Epoch 396/1200
#
# Epoch 00396: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0101 - val_loss: 0.2831
# Epoch 397/1200
#
# Epoch 00397: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0092 - val_loss: 0.3671
# Epoch 398/1200
#
# Epoch 00398: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0101 - val_loss: 0.2583
# Epoch 399/1200
#
# Epoch 00399: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0099 - val_loss: 0.3072
# Epoch 400/1200
#
# Epoch 00400: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0097 - val_loss: 0.2483
# Epoch 401/1200
#
# Epoch 00401: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0106 - val_loss: 0.3403
# Epoch 402/1200
#
# Epoch 00402: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0097 - val_loss: 0.1931
# Epoch 403/1200
#
# Epoch 00403: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0098 - val_loss: 0.3130
# Epoch 404/1200
#
# Epoch 00404: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0095 - val_loss: 0.1183
# Epoch 405/1200
#
# Epoch 00405: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0109 - val_loss: 0.2830
# Epoch 406/1200
#
# Epoch 00406: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0105 - val_loss: 0.2323
# Epoch 407/1200
#
# Epoch 00407: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0093 - val_loss: 0.2198
# Epoch 408/1200
#
# Epoch 00408: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0105 - val_loss: 0.2272
# Epoch 409/1200
#
# Epoch 00409: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0108 - val_loss: 0.1411
# Epoch 410/1200
#
# Epoch 00410: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0100 - val_loss: 0.2516
# Epoch 411/1200
#
# Epoch 00411: val_loss did not improve from 0.06731
# 634/634 - 3s - loss: 0.0096 - val_loss: 0.1883
# Epoch 412/1200
#
# Epoch 00412: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0118 - val_loss: 0.1441
# Epoch 413/1200
#
# Epoch 00413: val_loss did not improve from 0.06731
# 634/634 - 2s - loss: 0.0094 - val_loss: 0.1718
# Epoch 414/1200
#
# Epoch 00414: val_loss did not improve from 0.06731
# ...
# Epoch 1062/1200
#
# Epoch 01062: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0093 - val_loss: 0.2846
# Epoch 1063/1200
#
# Epoch 01063: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0090 - val_loss: 0.2763
# Epoch 1064/1200
#
# Epoch 01064: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0067 - val_loss: 0.2197
# Epoch 1065/1200
#
# Epoch 01065: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0068 - val_loss: 0.1759
# Epoch 1066/1200
#
# Epoch 01066: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0085 - val_loss: 0.2748
# Epoch 1067/1200
#
# Epoch 01067: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0067 - val_loss: 0.2367
# Epoch 1068/1200
#
# Epoch 01068: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0067 - val_loss: 0.1481
# Epoch 1069/1200
#
# Epoch 01069: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0067 - val_loss: 0.2880
# Epoch 1070/1200
#
# Epoch 01070: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0093 - val_loss: 0.2652
# Epoch 1071/1200
#
# Epoch 01071: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0091 - val_loss: 0.2857
# Epoch 1072/1200
#
# Epoch 01072: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0090 - val_loss: 0.4076
# Epoch 1073/1200
#
# Epoch 01073: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0089 - val_loss: 0.2734
# Epoch 1074/1200
#
# Epoch 01074: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0065 - val_loss: 0.1504
# Epoch 1075/1200
#
# Epoch 01075: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0065 - val_loss: 0.3188
# Epoch 1076/1200
#
# Epoch 01076: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0099 - val_loss: 0.1656
# Epoch 1077/1200
#
# Epoch 01077: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0088 - val_loss: 0.2864
# Epoch 1078/1200
#
# Epoch 01078: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0094 - val_loss: 0.2726
# Epoch 1079/1200
#
# Epoch 01079: val_loss did not improve from 0.05799
# 634/634 - 3s - loss: 0.0073 - val_loss: 0.2255
# Epoch 1080/1200
#
# Epoch 01080: val_loss did not improve from 0.05799
# 634/634 - 3s - loss: 0.0084 - val_loss: 0.1882
# Epoch 1081/1200
#
# Epoch 01081: val_loss did not improve from 0.05799
# 634/634 - 3s - loss: 0.0076 - val_loss: 0.2631
# Epoch 1082/1200
#
# Epoch 01082: val_loss did not improve from 0.05799
# 634/634 - 3s - loss: 0.0090 - val_loss: 0.2668
# Epoch 1083/1200
#
# Epoch 01083: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0066 - val_loss: 0.2331
# Epoch 1084/1200
#
# Epoch 01084: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0098 - val_loss: 0.2985
# Epoch 1085/1200
#
# Epoch 01085: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0095 - val_loss: 0.2627
# Epoch 1086/1200
#
# Epoch 01086: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0088 - val_loss: 0.1769
# Epoch 1087/1200
#
# Epoch 01087: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0085 - val_loss: 0.2518
# Epoch 1088/1200
#
# Epoch 01088: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0083 - val_loss: 0.1851
# Epoch 1089/1200
#
# Epoch 01089: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0082 - val_loss: 0.4447
# Epoch 1090/1200
#
# Epoch 01090: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0091 - val_loss: 0.2146
# Epoch 1091/1200
#
# Epoch 01091: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0090 - val_loss: 0.2343
# Epoch 1092/1200
#
# Epoch 01092: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0086 - val_loss: 0.1852
# Epoch 1093/1200
#
# Epoch 01093: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0081 - val_loss: 0.1566
# Epoch 1094/1200
#
# Epoch 01094: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0068 - val_loss: 0.1642
# Epoch 1095/1200
#
# Epoch 01095: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0074 - val_loss: 0.4409
# Epoch 1096/1200
#
# Epoch 01096: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0068 - val_loss: 0.2176
# Epoch 1097/1200
#
# Epoch 01097: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0068 - val_loss: 0.1494
# Epoch 1098/1200
#
# Epoch 01098: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0062 - val_loss: 0.1737
# Epoch 1099/1200
#
# Epoch 01099: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0088 - val_loss: 0.1795
# Epoch 1100/1200
#
# Epoch 01100: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0090 - val_loss: 0.1954
# Epoch 1101/1200
#
# Epoch 01101: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0085 - val_loss: 0.1404
# Epoch 1102/1200
#
# Epoch 01102: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0078 - val_loss: 0.3260
# Epoch 1103/1200
#
# Epoch 01103: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0077 - val_loss: 0.3397
# Epoch 1104/1200
#
# Epoch 01104: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0079 - val_loss: 0.2857
# Epoch 1105/1200
#
# Epoch 01105: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0077 - val_loss: 0.1894
# Epoch 1106/1200
#
# Epoch 01106: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0078 - val_loss: 0.1552
# Epoch 1107/1200
#
# Epoch 01107: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0087 - val_loss: 0.0809
# Epoch 1108/1200
#
# Epoch 01108: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0071 - val_loss: 0.2365
# Epoch 1109/1200
#
# Epoch 01109: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0068 - val_loss: 0.1109
# Epoch 1110/1200
#
# Epoch 01110: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0065 - val_loss: 0.2627
# Epoch 1111/1200
#
# Epoch 01111: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0090 - val_loss: 0.3041
# Epoch 1112/1200
#
# Epoch 01112: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0081 - val_loss: 0.3772
# Epoch 1113/1200
#
# Epoch 01113: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0075 - val_loss: 0.1080
# Epoch 1114/1200
#
# Epoch 01114: val_loss did not improve from 0.05799
# 634/634 - 3s - loss: 0.0078 - val_loss: 0.2874
# Epoch 1115/1200
#
# Epoch 01115: val_loss did not improve from 0.05799
# 634/634 - 3s - loss: 0.0080 - val_loss: 0.1794
# Epoch 1116/1200
#
# Epoch 01116: val_loss did not improve from 0.05799
# 634/634 - 3s - loss: 0.0073 - val_loss: 0.1447
# Epoch 1117/1200
#
# Epoch 01117: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0062 - val_loss: 0.1660
# Epoch 1118/1200
#
# Epoch 01118: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0067 - val_loss: 0.1690
# Epoch 1119/1200
#
# Epoch 01119: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0075 - val_loss: 0.3380
# Epoch 1120/1200
#
# Epoch 01120: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0064 - val_loss: 0.2090
# Epoch 1121/1200
#
# Epoch 01121: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0066 - val_loss: 0.3398
# Epoch 1122/1200
#
# Epoch 01122: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0085 - val_loss: 0.2093
# Epoch 1123/1200
#
# Epoch 01123: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0069 - val_loss: 0.1712
# Epoch 1124/1200
#
# Epoch 01124: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0066 - val_loss: 0.3174
# Epoch 1125/1200
#
# Epoch 01125: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0085 - val_loss: 0.2355
# Epoch 1126/1200
#
# Epoch 01126: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0066 - val_loss: 0.2952
# Epoch 1127/1200
#
# Epoch 01127: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0074 - val_loss: 0.1726
# Epoch 1128/1200
#
# Epoch 01128: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0065 - val_loss: 0.2412
# Epoch 1129/1200
#
# Epoch 01129: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0079 - val_loss: 0.2415
# Epoch 1130/1200
#
# Epoch 01130: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0074 - val_loss: 0.1931
# Epoch 1131/1200
#
# Epoch 01131: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0081 - val_loss: 0.3847
# Epoch 1132/1200
#
# Epoch 01132: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0085 - val_loss: 0.2692
# Epoch 1133/1200
#
# Epoch 01133: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0078 - val_loss: 0.1700
# Epoch 1134/1200
#
# Epoch 01134: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0073 - val_loss: 0.1522
# Epoch 1135/1200
#
# Epoch 01135: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0071 - val_loss: 0.4759
# Epoch 1136/1200
#
# Epoch 01136: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0093 - val_loss: 0.1271
# Epoch 1137/1200
#
# Epoch 01137: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0073 - val_loss: 0.3795
# Epoch 1138/1200
#
# Epoch 01138: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0073 - val_loss: 0.3234
# Epoch 1139/1200
#
# Epoch 01139: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0075 - val_loss: 0.3527
# Epoch 1140/1200
#
# Epoch 01140: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0067 - val_loss: 0.3834
# Epoch 1141/1200
#
# Epoch 01141: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0085 - val_loss: 0.3343
# Epoch 1142/1200
#
# Epoch 01142: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0077 - val_loss: 0.3577
# Epoch 1143/1200
#
# Epoch 01143: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0084 - val_loss: 0.3428
# Epoch 1144/1200
#
# Epoch 01144: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0076 - val_loss: 0.2781
# Epoch 1145/1200
#
# Epoch 01145: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0091 - val_loss: 0.2845
# Epoch 1146/1200
#
# Epoch 01146: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0069 - val_loss: 0.1671
# Epoch 1147/1200
#
# Epoch 01147: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0063 - val_loss: 0.3241
# Epoch 1148/1200
#
# Epoch 01148: val_loss did not improve from 0.05799
# 634/634 - 3s - loss: 0.0065 - val_loss: 0.1817
# Epoch 1149/1200
#
# Epoch 01149: val_loss did not improve from 0.05799
# 634/634 - 3s - loss: 0.0075 - val_loss: 0.2568
# Epoch 1150/1200
#
# Epoch 01150: val_loss did not improve from 0.05799
# 634/634 - 3s - loss: 0.0071 - val_loss: 0.2314
# Epoch 1151/1200
#
# Epoch 01151: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0073 - val_loss: 0.2468
# Epoch 1152/1200
#
# Epoch 01152: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0065 - val_loss: 0.1563
# Epoch 1153/1200
#
# Epoch 01153: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0067 - val_loss: 0.2588
# Epoch 1154/1200
#
# Epoch 01154: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0066 - val_loss: 0.1922
# Epoch 1155/1200
#
# Epoch 01155: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0071 - val_loss: 0.1663
# Epoch 1156/1200
#
# Epoch 01156: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0070 - val_loss: 0.1781
# Epoch 1157/1200
#
# Epoch 01157: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0077 - val_loss: 0.2558
# Epoch 1158/1200
#
# Epoch 01158: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0063 - val_loss: 0.1849
# Epoch 1159/1200
#
# Epoch 01159: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0065 - val_loss: 0.2745
# Epoch 1160/1200
#
# Epoch 01160: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0066 - val_loss: 0.2397
# Epoch 1161/1200
#
# Epoch 01161: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0068 - val_loss: 0.3096
# Epoch 1162/1200
#
# Epoch 01162: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0084 - val_loss: 0.3300
# Epoch 1163/1200
#
# Epoch 01163: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0067 - val_loss: 0.2124
# Epoch 1164/1200
#
# Epoch 01164: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0063 - val_loss: 0.2713
# Epoch 1165/1200
#
# Epoch 01165: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0065 - val_loss: 0.1672
# Epoch 1166/1200
#
# Epoch 01166: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0075 - val_loss: 0.3488
# Epoch 1167/1200
#
# Epoch 01167: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0077 - val_loss: 0.2758
# Epoch 1168/1200
#
# Epoch 01168: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0061 - val_loss: 0.2839
# Epoch 1169/1200
#
# Epoch 01169: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0065 - val_loss: 0.3365
# Epoch 1170/1200
#
# Epoch 01170: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0101 - val_loss: 0.1662
# Epoch 1171/1200
#
# Epoch 01171: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0073 - val_loss: 0.3635
# Epoch 1172/1200
#
# Epoch 01172: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0071 - val_loss: 0.4366
# Epoch 1173/1200
#
# Epoch 01173: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0089 - val_loss: 0.3101
# Epoch 1174/1200
#
# Epoch 01174: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0078 - val_loss: 0.1336
# Epoch 1175/1200
#
# Epoch 01175: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0079 - val_loss: 0.2545
# Epoch 1176/1200
#
# Epoch 01176: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0068 - val_loss: 0.2347
# Epoch 1177/1200
#
# Epoch 01177: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0103 - val_loss: 0.2028
# Epoch 1178/1200
#
# Epoch 01178: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0067 - val_loss: 0.2103
# Epoch 1179/1200
#
# Epoch 01179: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0068 - val_loss: 0.2661
# Epoch 1180/1200
#
# Epoch 01180: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0074 - val_loss: 0.1674
# Epoch 1181/1200
#
# Epoch 01181: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0062 - val_loss: 0.2691
# Epoch 1182/1200
#
# Epoch 01182: val_loss did not improve from 0.05799
# 634/634 - 3s - loss: 0.0065 - val_loss: 0.0934
# Epoch 1183/1200
#
# Epoch 01183: val_loss did not improve from 0.05799
# 634/634 - 3s - loss: 0.0063 - val_loss: 0.3440
# Epoch 1184/1200
#
# Epoch 01184: val_loss did not improve from 0.05799
# 634/634 - 3s - loss: 0.0063 - val_loss: 0.3281
# Epoch 1185/1200
#
# Epoch 01185: val_loss did not improve from 0.05799
# 634/634 - 3s - loss: 0.0060 - val_loss: 0.2816
# Epoch 1186/1200
#
# Epoch 01186: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0068 - val_loss: 0.2144
# Epoch 1187/1200
#
# Epoch 01187: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0075 - val_loss: 0.1962
# Epoch 1188/1200
#
# Epoch 01188: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0071 - val_loss: 0.1498
# Epoch 1189/1200
#
# Epoch 01189: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0064 - val_loss: 0.3803
# Epoch 1190/1200
#
# Epoch 01190: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0071 - val_loss: 0.1922
# Epoch 1191/1200
#
# Epoch 01191: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0069 - val_loss: 0.1828
# Epoch 1192/1200
#
# Epoch 01192: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0063 - val_loss: 0.4036
# Epoch 1193/1200
#
# Epoch 01193: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0073 - val_loss: 0.2701
# Epoch 1194/1200
#
# Epoch 01194: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0073 - val_loss: 0.2216
# Epoch 1195/1200
#
# Epoch 01195: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0069 - val_loss: 0.2876
# Epoch 1196/1200
#
# Epoch 01196: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0076 - val_loss: 0.2039
# Epoch 1197/1200
#
# Epoch 01197: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0060 - val_loss: 0.2669
# Epoch 1198/1200
#
# Epoch 01198: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0062 - val_loss: 0.2371
# Epoch 1199/1200
#
# Epoch 01199: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0076 - val_loss: 0.3679
# Epoch 1200/1200
#
# Epoch 01200: val_loss did not improve from 0.05799
# 634/634 - 2s - loss: 0.0072 - val_loss: 0.1945

# %%
# from google.colab import files
# files.download(model_filename)

# %%
# Load the Model file and do the inference

def forecast(train_scaled=train_scaled,test_scaled=test_scaled):  
  model_from_file = load_model(checkpoint_dir + model_filename)

  # forecast the entire training dataset to build up state for forecasting
  train_reshaped = train_scaled[:, 0].reshape(len(train_scaled), 1, 1)
  model_from_file.predict(train_reshaped, batch_size=1)

  # walk-forward validation on the test data
  predictions = list()
  for i in range(len(test_scaled)):
      # make one-step forecast
      X, y = test_scaled[i, 0:-1], test_scaled[i, -1]
      yhat = forecast_lstm(model_from_file, 1, X)
      # invert scaling
      yhat = invert_scale(scaler, X, yhat)
      # invert differencing
      yhat = inverse_difference(raw_values, yhat, len(test_scaled)+1-i)
      # store forecast
      predictions.append(yhat)
      expected = raw_values[len(train) + i + 1]
#       print('day=%d, Predicted=%f, Expected=%f' % (i+1, yhat, expected))  
      
  
  df_out = pd.DataFrame(df_raw[-14:]['sale_amt'])
  df_out.columns=['Original']
  df_out['Predicted'] = predictions
  
  
  return df_out

# %%
df_pred = forecast()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0519 03:58:58.367589 139899815688064 tf_logging.py:161] <tensorflow.python.keras.layers.recurrent.UnifiedLSTM object at 0x7f3c8082d438>: Note that this layer is not optimized for performance. Please use tf.keras.layers.CuDNNLSTM for better performance on GPU.
# W0519 03:58:59.064797 139899815688064 tf_logging.py:161] <tensorflow.python.keras.layers.recurrent.UnifiedLSTM object at 0x7f3c80825b70>: Note that this layer is not optimized for performance. Please use tf.keras.layers.CuDNNLSTM for better performance on GPU.

# %%
configure_plotly_browser_state()
plotly_df(df_pred, title='Predictions', forecast = True)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div id="9bdfd8b9-2df1-4b3c-a65a-3fedc2c0f333" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9bdfd8b9-2df1-4b3c-a65a-3fedc2c0f333", [{"mode": "lines+markers", "name": "Original", "x": ["2019-04-01", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14"], "y": [137732.51, 149899.28, 89982.3, 80733.34, 67755.3, 0.0, 0.0, 144153.1, 142016.79, 72274.39, 64476.74, 61764.18, 0.0, 0.0], "type": "scatter", "uid": "e7f3d8a8-96ec-493b-9243-214fc1c26ed7"}, {"mode": "lines+markers", "name": "Predicted", "x": ["2019-04-01", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14"], "y": [131013.89304428341, 140047.23111722546, 83641.12017296972, 77741.61687260399, 69277.29363592596, -1345.3812192117912, 4188.138750631155, 114579.55658952237, 138682.68986127374, 83461.91996779846, 86698.86876680137, 65111.75826251352, -1301.7075568246655, 575.049726496057], "type": "scatter", "uid": "f62a8494-140e-4db6-8a83-d7411def3285"}], {"showlegend": true, "title": {"text": "Predictions"}, "xaxis": {"rangeslider": {"visible": false}, "title": {"text": "Time Steps"}, "type": "date"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("9bdfd8b9-2df1-4b3c-a65a-3fedc2c0f333"));});</script>

# %%
configure_plotly_browser_state()
plotly_df(df_raw, title='Timeseries')
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div id="d05ba832-0254-4448-9ef7-791838bedc9f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d05ba832-0254-4448-9ef7-791838bedc9f", [{"mode": "lines+markers", "name": "sale_amt", "x": ["2017-07-05", "2017-07-06", "2017-07-07", "2017-07-08", "2017-07-09", "2017-07-10", "2017-07-11", "2017-07-12", "2017-07-13", "2017-07-14", "2017-07-15", "2017-07-16", "2017-07-17", "2017-07-18", "2017-07-19", "2017-07-20", "2017-07-21", "2017-07-22", "2017-07-23", "2017-07-24", "2017-07-25", "2017-07-26", "2017-07-27", "2017-07-28", "2017-07-29", "2017-07-30", "2017-07-31", "2017-08-01", "2017-08-02", "2017-08-03", "2017-08-04", "2017-08-05", "2017-08-06", "2017-08-07", "2017-08-08", "2017-08-09", "2017-08-10", "2017-08-11", "2017-08-12", "2017-08-13", "2017-08-14", "2017-08-15", "2017-08-16", "2017-08-17", "2017-08-18", "2017-08-19", "2017-08-20", "2017-08-21", "2017-08-22", "2017-08-23", "2017-08-24", "2017-08-25", "2017-08-26", "2017-08-27", "2017-08-28", "2017-08-29", "2017-08-30", "2017-08-31", "2017-09-01", "2017-09-02", "2017-09-03", "2017-09-04", "2017-09-05", "2017-09-06", "2017-09-07", "2017-09-08", "2017-09-09", "2017-09-10", "2017-09-11", "2017-09-12", "2017-09-13", "2017-09-14", "2017-09-15", "2017-09-16", "2017-09-17", "2017-09-18", "2017-09-19", "2017-09-20", "2017-09-21", "2017-09-22", "2017-09-23", "2017-09-24", "2017-09-25", "2017-09-26", "2017-09-27", "2017-09-28", "2017-09-29", "2017-09-30", "2017-10-01", "2017-10-02", "2017-10-03", "2017-10-04", "2017-10-05", "2017-10-06", "2017-10-07", "2017-10-08", "2017-10-09", "2017-10-10", "2017-10-11", "2017-10-12", "2017-10-13", "2017-10-14", "2017-10-15", "2017-10-16", "2017-10-17", "2017-10-18", "2017-10-19", "2017-10-20", "2017-10-21", "2017-10-22", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-28", "2017-10-29", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-04", "2017-11-05", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-11", "2017-11-12", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-18", "2017-11-19", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-23", "2017-11-24", "2017-11-25", "2017-11-26", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-02", "2017-12-03", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-09", "2017-12-10", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-16", "2017-12-17", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-23", "2017-12-24", "2017-12-25", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2017-12-30", "2017-12-31", "2018-01-01", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-06", "2018-01-07", "2018-01-08", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-13", "2018-01-14", "2018-01-15", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-20", "2018-01-21", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-27", "2018-01-28", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-02", "2018-02-03", "2018-02-04", "2018-02-05", "2018-02-06", "2018-02-07", "2018-02-08", "2018-02-09", "2018-02-10", "2018-02-11", "2018-02-12", "2018-02-13", "2018-02-14", "2018-02-15", "2018-02-16", "2018-02-17", "2018-02-18", "2018-02-19", "2018-02-20", "2018-02-21", "2018-02-22", "2018-02-23", "2018-02-24", "2018-02-25", "2018-02-26", "2018-02-27", "2018-02-28", "2018-03-01", "2018-03-02", "2018-03-03", "2018-03-04", "2018-03-05", "2018-03-06", "2018-03-07", "2018-03-08", "2018-03-09", "2018-03-10", "2018-03-11", "2018-03-12", "2018-03-13", "2018-03-14", "2018-03-15", "2018-03-16", "2018-03-17", "2018-03-18", "2018-03-19", "2018-03-20" ...

# %%
rmse = math.sqrt(mean_squared_error(df_pred['Original'].values, df_pred['Predicted'].values))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 11119.342

# %%
mape = mean_absolute_percentage_error(np.array(df_pred['Predicted'].values),np.array(df_pred['Original'].values))
print ('Test MAPE: %.3f' %mape)
# Out:
# Test MAPE: 7.013

# %%
err = (abs(sum(df_pred['Predicted'].values) - sum(df_pred['Original'].values)) / (sum(df_pred['Original'].values))) *100
print ('Prediction Error: %.2f%%' %err)
# Out:
# Prediction Error: 1.82%
