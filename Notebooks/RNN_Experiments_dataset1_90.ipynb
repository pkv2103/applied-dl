# %%
# !pip install -q tensorflow-gpu==2.0.0-alpha0

# %% [markdown]
# **Get Model files and Datasets from cloud APIs**

# %%
# !wget https://storage.googleapis.com/columbia_applied_deep_learning/demand_forecasting.zip  \
    -O ./demand_forecasting.zip
# Out:
# --2019-05-19 04:51:49--  https://storage.googleapis.com/columbia_applied_deep_learning/demand_forecasting.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 209.85.145.128, 2607:f8b0:4001:c07::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|209.85.145.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3361698 (3.2M) [application/zip]
# Saving to: ‘./demand_forecasting.zip’
#
# ./demand_forecastin 100%[===================>]   3.21M  --.-KB/s    in 0.02s
#
# 2019-05-19 04:51:49 (173 MB/s) - ‘./demand_forecasting.zip’ saved [3361698/3361698]

# %%
import zipfile
local_zip = './demand_forecasting.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall('./')
zip_ref.close()

# %%
# !ls -al
# Out:
# total 7284
# drwxr-xr-x 1 root root    4096 May 19 04:35 .
# drwxr-xr-x 1 root root    4096 May 19 04:33 ..
# drwxr-xr-x 1 root root    4096 May 16 16:08 .config
# -rw-r--r-- 1 root root 3361698 May 19 03:13 demand_forecasting.zip
# drwxr-xr-x 2 root root    4096 May 19 04:35 __MACOSX
# -rw-r--r-- 1 root root  189008 May 19 04:51 model1_eu.hdf5
# -rw-r--r-- 1 root root  188968 May 19 04:51 model1_id2.hdf5
# -rw-r--r-- 1 root root  171048 May 19 04:51 model1_th.hdf5
# -rw-r--r-- 1 root root  901416 May 19 04:51 model2_eu.hdf5
# -rw-r--r-- 1 root root  901312 May 19 04:51 model2_id2.hdf5
# -rw-r--r-- 1 root root  901312 May 19 04:51 model2_th.hdf5
# -rw-r--r-- 1 root root  150744 May 19 04:51 model3_eu.hdf5
# -rw-r--r-- 1 root root  150744 May 19 04:51 model3_id2.hdf5
# -rw-r--r-- 1 root root  150744 May 19 04:51 model3_th_exp_120.hdf5
# -rw-r--r-- 1 root root  150744 May 19 04:51 model3_th_exp.hdf5
# -rw-r--r-- 1 root root  142760 May 19 04:51 model3_th.hdf5
# -rw-r--r-- 1 root root    8090 May 19 04:51 Product1-Dataset-th-1year.csv
# -rw-r--r-- 1 root root   12721 May 19 04:51 Product1-Dataset-th-2year.csv
# -rw-r--r-- 1 root root   14346 May 19 04:51 Product2-Dataset-id-2year.csv
# -rw-r--r-- 1 root root   11829 May 19 04:51 Product3-Dataset-eu-2year.csv
# drwxr-xr-x 1 root root    4096 May 15 16:23 sample_data

# %% [markdown]
# **Imports**

# %%
import pandas as pd
import numpy as np
import argparse
import os
import platform
import datetime, time
import datetime as dt
import warnings
from IPython.core.display import display, HTML
import tensorflow as tf
from plotly.offline import init_notebook_mode, iplot
from plotly import graph_objs as go
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dense, Dropout, SimpleRNN, Input, LSTM, TimeDistributed,RepeatVector, Flatten
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, EarlyStopping, ReduceLROnPlateau,RemoteMonitor
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from tensorflow.keras.models import load_model
import sys
import math

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
plt.style.use('default')
plt.style.use('seaborn-deep')
sns.set(style="whitegrid")
sns.set_context("talk")

# %matplotlib inline
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
checkpoint_dir = './'
model_filename = 'model3_th_exp.hdf5'
data_filename = 'Product1-Dataset-th-2year.csv'
train_model = 'False'

# %%
tf.__version__
# Out:
# '2.0.0-alpha0'

# %%
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

# %%
def plotly_df(df, title='', annotations=None):
    """Visualize all the dataframe columns as line plots."""
    common_kw = dict(x=df.index, mode='lines+markers')
    xaxis = dict(title='Time Steps',type='date', rangeslider=dict(visible=True))
    
    data = [go.Scatter(y=df[c], name=c,  **common_kw) for c in df.columns]
    layout = dict(title=title, showlegend=True, annotations=annotations, xaxis=xaxis, )
    fig = dict(data=data, layout=layout)
    iplot(fig, show_link=False)

# %%
def create_timeseries_dataset(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var_lag%d(t-%d)' % (j+1, i)) for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var_roll%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var_roll%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
def timeseries_train_test_split(X, test_size):
    """
        Perform train-test split with respect to time series structure
    """
    
    # get the index after which test set starts
    test_index = int(len(X)*(1-test_size))
    
    train = X[:test_index]
    test = X[test_index:]
    
    return train, test

# %% [markdown]
# **Read the Dataset & add index**

# %%
df_raw = pd.read_csv(filepath_or_buffer=data_filename, header=0, names=None, usecols=['date', 'sale_amt'], parse_dates=[0])

# %%
df_raw.index = df_raw.date
df_raw.drop(['date'], inplace=True, axis=1)

# %% [markdown]
# **Plot the dataset**

# %%
configure_plotly_browser_state()
plotly_df(df_raw, title='Timeseries')
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div id="14443811-a84e-4340-bc73-7d5e2af123f2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("14443811-a84e-4340-bc73-7d5e2af123f2", [{"mode": "lines+markers", "name": "sale_amt", "x": ["2017-05-15", "2017-05-16", "2017-05-17", "2017-05-18", "2017-05-19", "2017-05-20", "2017-05-21", "2017-05-22", "2017-05-23", "2017-05-24", "2017-05-25", "2017-05-26", "2017-05-27", "2017-05-28", "2017-05-29", "2017-05-30", "2017-05-31", "2017-06-01", "2017-06-02", "2017-06-03", "2017-06-04", "2017-06-05", "2017-06-06", "2017-06-07", "2017-06-08", "2017-06-09", "2017-06-10", "2017-06-11", "2017-06-12", "2017-06-13", "2017-06-14", "2017-06-15", "2017-06-16", "2017-06-17", "2017-06-18", "2017-06-19", "2017-06-20", "2017-06-21", "2017-06-22", "2017-06-23", "2017-06-24", "2017-06-25", "2017-06-26", "2017-06-27", "2017-06-28", "2017-06-29", "2017-06-30", "2017-07-01", "2017-07-02", "2017-07-03", "2017-07-04", "2017-07-05", "2017-07-
11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-16", "2017-12-17", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-23", "2017-12-24", "2017-12-25", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2017-12-30", "2017-12-31", "2018-01-01", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-06", "2018-01-07", "2018-01-08", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-13", "2018-01-14", "2018-01-15", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-20", "2018-01-21", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-27", "2018-01-28", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-02", "2018-02-03", "2018-02-04", "2018-02-05", "2018-02-06", "2018-02-07", "2018-02-08", "2018-02-09", "2018-02-10", "2018-02-11", "2018-02-12", "2018-02-13", "2018-02-14", "2018-02-15", "2018-02-16", "2018-02-17", "2018-02-18", "2018-02-19", "2018-02-20", "2018-02-21", "2018-02-22", "2018-02-23", "2018-02-24", "2018-02-25", "2018-02-26", "2018-02-27", "2018-02-28", "2018-03-01", "2018-03-02", "2018-03-03", "2018-03-04", "2018-03-05", "2018-03-06", "2018-03-07", "2018-03-08", "2018-03-09", "2018-03-10", "2018-03-11", "2018-03-12", "2018-03-13", "2018-03-14", "2018-03-15", "2018-03-16", "2018-03-17", "2018-03-18", "2018-03-19", "2018-03-20", "2018-03-21", "2018-03-22", "2018-03-23", "2018-03-24", "2018-03-25", "2018-03-26", "2018-03-27", "2018-03-28", "2018-03-29" ...

# %% [markdown]
# **Convert the data to timeseries format; Split the data into test and training sets**

# %%
timesteps=90
rolling_days=14
df_to_ts = create_timeseries_dataset(df_raw, n_in=timesteps, n_out=rolling_days, dropnan=True)

# %%
train_dataset, test_dataset = timeseries_train_test_split(df_to_ts, 0.12)

# %%
print (train_dataset.shape, test_dataset.shape)
# Out:
# (465, 104) (64, 104)

# %% [markdown]
# **Scale the data using MinMaxScaler**

# %%
scaler = MinMaxScaler(feature_range=(-1,1))
scaler.fit(train_dataset)

train_scaled = scaler.transform(train_dataset)
test_scaled = scaler.transform(test_dataset)

x_train_scaled = train_scaled[:, :timesteps]
y_train_scaled = train_scaled[:, timesteps:]

x_test_scaled = test_scaled[:, :timesteps]
y_test_scaled = test_scaled[:, timesteps:]

print('test_scaled shape: '  + str(test_scaled.shape))
print('train_scaled shape: '  + str(train_scaled.shape))
# Out:
# test_scaled shape: (64, 104)
# train_scaled shape: (465, 104)

# %% [markdown]
# **Model Definition**

# %%
timesteps=90
rolling_days=14

model = tf.keras.Sequential()
model.add(tf.keras.layers.Reshape((timesteps, 1), input_shape=(timesteps,)))
model.add(tf.keras.layers.SimpleRNN(64, return_sequences=True))
model.add(tf.keras.layers.SimpleRNN(32, return_sequences=False))
model.add(tf.keras.layers.Dense(32))
model.add(tf.keras.layers.Dense(rolling_days))
model.compile('adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape (Reshape)            (None, 90, 1)             0
# _________________________________________________________________
# simple_rnn (SimpleRNN)       (None, 90, 64)            4224
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 32)                3104
# _________________________________________________________________
# dense (Dense)                (None, 32)                1056
# _________________________________________________________________
# dense_1 (Dense)              (None, 14)                462
# =================================================================
# Total params: 8,846
# Trainable params: 8,846
# Non-trainable params: 0
# _________________________________________________________________

# %%
validation_data = (x_test_scaled, y_test_scaled)
c = [
      ModelCheckpoint(checkpoint_dir + model_filename, save_best_only=True,monitor='val_loss', mode='min', verbose=1, period=1),
      EarlyStopping(monitor='val_loss', min_delta=0, patience=200, verbose=1),
      ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=55, min_lr=0.000001, verbose=1)]

# %%
if train_model:
  history = model.fit(x_train_scaled, y_train_scaled, epochs=1500,verbose=1, batch_size=14, validation_data=validation_data, callbacks=c, shuffle=False)
# Out:
# Train on 465 samples, validate on 64 samples
# Epoch 1/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.1206
# Epoch 00001: val_loss improved from inf to 0.05275, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 22s 48ms/sample - loss: 0.1201 - val_loss: 0.0527
# Epoch 2/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0398
# Epoch 00002: val_loss improved from 0.05275 to 0.03917, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 44ms/sample - loss: 0.0398 - val_loss: 0.0392
# Epoch 3/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0358
# Epoch 00003: val_loss improved from 0.03917 to 0.03323, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 19s 42ms/sample - loss: 0.0357 - val_loss: 0.0332
# Epoch 4/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0324
# Epoch 00004: val_loss improved from 0.03323 to 0.02885, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 19s 41ms/sample - loss: 0.0324 - val_loss: 0.0288
# Epoch 5/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0296
# Epoch 00005: val_loss improved from 0.02885 to 0.02478, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 19s 42ms/sample - loss: 0.0295 - val_loss: 0.0248
# Epoch 6/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0273
# Epoch 00006: val_loss improved from 0.02478 to 0.02140, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 21s 45ms/sample - loss: 0.0272 - val_loss: 0.0214
# Epoch 7/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0258
# Epoch 00007: val_loss improved from 0.02140 to 0.01938, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 43ms/sample - loss: 0.0257 - val_loss: 0.0194
# Epoch 8/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0246
# Epoch 00008: val_loss improved from 0.01938 to 0.01845, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 42ms/sample - loss: 0.0246 - val_loss: 0.0184
# Epoch 9/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0238
# Epoch 00009: val_loss improved from 0.01845 to 0.01788, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 21s 45ms/sample - loss: 0.0237 - val_loss: 0.0179
# Epoch 10/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0232
# Epoch 00010: val_loss improved from 0.01788 to 0.01761, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 43ms/sample - loss: 0.0232 - val_loss: 0.0176
# Epoch 11/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0230
# Epoch 00011: val_loss improved from 0.01761 to 0.01753, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 42ms/sample - loss: 0.0229 - val_loss: 0.0175
# Epoch 12/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0231
# Epoch 00012: val_loss improved from 0.01753 to 0.01744, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 42ms/sample - loss: 0.0230 - val_loss: 0.0174
# Epoch 13/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0233
# Epoch 00013: val_loss improved from 0.01744 to 0.01697, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 44ms/sample - loss: 0.0232 - val_loss: 0.0170
# Epoch 14/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0231
# Epoch 00014: val_loss improved from 0.01697 to 0.01665, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 44ms/sample - loss: 0.0230 - val_loss: 0.0167
# Epoch 15/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0224
# Epoch 00015: val_loss improved from 0.01665 to 0.01657, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 19s 42ms/sample - loss: 0.0223 - val_loss: 0.0166
# Epoch 16/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0220
# Epoch 00016: val_loss improved from 0.01657 to 0.01641, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 21s 45ms/sample - loss: 0.0219 - val_loss: 0.0164
# Epoch 17/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0219
# Epoch 00017: val_loss improved from 0.01641 to 0.01621, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 44ms/sample - loss: 0.0218 - val_loss: 0.0162
# Epoch 18/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0218
# Epoch 00018: val_loss improved from 0.01621 to 0.01604, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 43ms/sample - loss: 0.0217 - val_loss: 0.0160
# Epoch 19/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0218
# Epoch 00019: val_loss improved from 0.01604 to 0.01589, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 43ms/sample - loss: 0.0217 - val_loss: 0.0159
# Epoch 20/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0218
# Epoch 00020: val_loss improved from 0.01589 to 0.01565, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 42ms/sample - loss: 0.0217 - val_loss: 0.0157
# Epoch 21/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0217
# Epoch 00021: val_loss improved from 0.01565 to 0.01529, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 44ms/sample - loss: 0.0216 - val_loss: 0.0153
# Epoch 22/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0214
# Epoch 00022: val_loss improved from 0.01529 to 0.01498, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 21s 44ms/sample - loss: 0.0213 - val_loss: 0.0150
# Epoch 23/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0212
# Epoch 00023: val_loss improved from 0.01498 to 0.01472, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 42ms/sample - loss: 0.0211 - val_loss: 0.0147
# Epoch 24/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0211
# Epoch 00024: val_loss improved from 0.01472 to 0.01447, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 42ms/sample - loss: 0.0210 - val_loss: 0.0145
# Epoch 25/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0210
# Epoch 00025: val_loss improved from 0.01447 to 0.01422, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 44ms/sample - loss: 0.0209 - val_loss: 0.0142
# Epoch 26/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0209
# Epoch 00026: val_loss improved from 0.01422 to 0.01399, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 21s 45ms/sample - loss: 0.0208 - val_loss: 0.0140
# Epoch 27/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0208
# Epoch 00027: val_loss improved from 0.01399 to 0.01380, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 42ms/sample - loss: 0.0207 - val_loss: 0.0138
# Epoch 28/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0207
# Epoch 00028: val_loss improved from 0.01380 to 0.01366, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 43ms/sample - loss: 0.0206 - val_loss: 0.0137
# Epoch 29/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0207
# Epoch 00029: val_loss improved from 0.01366 to 0.01355, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 43ms/sample - loss: 0.0206 - val_loss: 0.0136
# Epoch 30/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0206
# Epoch 00030: val_loss improved from 0.01355 to 0.01346, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 21s 45ms/sample - loss: 0.0205 - val_loss: 0.0135
# Epoch 31/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0206
# Epoch 00031: val_loss improved from 0.01346 to 0.01336, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 21s 44ms/sample - loss: 0.0205 - val_loss: 0.0134
# Epoch 32/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0205
# Epoch 00032: val_loss improved from 0.01336 to 0.01320, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 19s 41ms/sample - loss: 0.0204 - val_loss: 0.0132
# Epoch 33/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0205
# Epoch 00033: val_loss improved from 0.01320 to 0.01301, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 19s 42ms/sample - loss: 0.0204 - val_loss: 0.0130
# Epoch 34/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0204
# Epoch 00034: val_loss improved from 0.01301 to 0.01283, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 43ms/sample - loss: 0.0203 - val_loss: 0.0128
# Epoch 35/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0203
# Epoch 00035: val_loss improved from 0.01283 to 0.01271, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 19s 41ms/sample - loss: 0.0202 - val_loss: 0.0127
# Epoch 36/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0202
# Epoch 00036: val_loss improved from 0.01271 to 0.01262, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 43ms/sample - loss: 0.0200 - val_loss: 0.0126
# Epoch 37/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0200
# Epoch 00037: val_loss improved from 0.01262 to 0.01257, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 42ms/sample - loss: 0.0199 - val_loss: 0.0126
# Epoch 38/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0199
# Epoch 00038: val_loss improved from 0.01257 to 0.01254, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 21s 46ms/sample - loss: 0.0198 - val_loss: 0.0125
# Epoch 39/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0199
# Epoch 00039: val_loss improved from 0.01254 to 0.01253, saving model to /content/model3_th_exp.hdf5
# 465/465 [==============================] - 20s 43ms/sample - loss: 0.0198 - val_loss: 0.0125
# Epoch 40/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.
1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0108
# Epoch 00202: val_loss did not improve from 0.01253
#
# Epoch 00202: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 203/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00203: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 204/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00204: val_loss did not improve from 0.01253
# 465/465 [==============================] - 10s 21ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 205/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00205: val_loss did not improve from 0.01253
# 465/465 [==============================] - 9s 20ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 206/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00206: val_loss did not improve from 0.01253
# 465/465 [==============================] - 9s 19ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 207/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00207: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 208/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00208: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 209/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00209: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 210/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00210: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 211/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00211: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 212/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00212: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 213/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00213: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 214/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00214: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 215/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00215: val_loss did not improve from 0.01253
# 465/465 [==============================] - 11s 23ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 216/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00216: val_loss did not improve from 0.01253
# 465/465 [==============================] - 10s 21ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 217/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00217: val_loss did not improve from 0.01253
# 465/465 [==============================] - 10s 21ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 218/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00218: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 219/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00219: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 220/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00220: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 221/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00221: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 222/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00222: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 223/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00223: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 224/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00224: val_loss did not improve from 0.01253
# 465/465 [==============================] - 10s 21ms/sample - loss: 0.0107 - val_loss: 0.0259
# Epoch 225/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00225: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0260
# Epoch 226/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00226: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0260
# Epoch 227/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00227: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0260
# Epoch 228/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00228: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0260
# Epoch 229/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00229: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0260
# Epoch 230/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00230: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0260
# Epoch 231/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00231: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0260
# Epoch 232/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00232: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0107 - val_loss: 0.0260
# Epoch 233/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00233: val_loss did not improve from 0.01253
# 465/465 [==============================] - 9s 19ms/sample - loss: 0.0107 - val_loss: 0.0260
# Epoch 234/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00234: val_loss did not improve from 0.01253
# 465/465 [==============================] - 9s 20ms/sample - loss: 0.0106 - val_loss: 0.0260
# Epoch 235/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00235: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0106 - val_loss: 0.0260
# Epoch 236/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00236: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 17ms/sample - loss: 0.0106 - val_loss: 0.0260
# Epoch 237/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00237: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0106 - val_loss: 0.0260
# Epoch 238/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00238: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0106 - val_loss: 0.0260
# Epoch 239/1500
# 462/465 [============================>.] - ETA: 0s - loss: 0.0107
# Epoch 00239: val_loss did not improve from 0.01253
# 465/465 [==============================] - 8s 18ms/sample - loss: 0.0106 - val_loss: 0.0260
# Epoch 00239: early stopping

# %% [markdown]
# **Save the model for future prediction**

# %%
# from google.colab import files
# files.download(model_filename)

# %% [markdown]
# **Plot Training and Validation loss**

# %%
if train_model:  
  plt.style.use('default')
  fig, ax = plt.subplots(facecolor='w')
  fig.set_size_inches(fig.get_figwidth() * 2.0, fig.get_figheight() * 1.0)

  ax.plot(history.history['loss'])
  ax.plot(history.history['val_loss'])

  plt.xlabel('Epoch')
  plt.ylabel('MSE Loss')
  plt.title('Loss Over Time')
  plt.legend(['Train','Valid'])
  plt.show()

# %% [markdown]
# **Load saved model for predictions**

# %%
model_from_file = load_model(checkpoint_dir + model_filename)

# %% [markdown]
# **This function predicts on the training dataset and returns Original and Predicted values as two separate dataframes**

# %%
def inverse_transform_out(scaler=scaler, x_scaled=x_test_scaled, y_scaled=y_test_scaled, dataset=test_dataset, from_model=model):
  
  # This function creates dataframes for true and predicted values. It can be called for train, test and validation datasets. 
  # Uses the model, scaler and scaled datasets as inputs
  # output is two dataframes; one for true rolling days values and the other for predictions
  
  yhat = from_model.predict(x_scaled)
  
  pred_cols = ['pred_'+str(i) for i in range(1, rolling_days+1)]
  scaler_input = np.concatenate([x_scaled, yhat], axis=1)
  scaler_output = scaler.inverse_transform(scaler_input)
  df_pred = pd.DataFrame(scaler_output[:, timesteps:],columns=pred_cols)
  df_pred.index = dataset.index
  
  true_cols = ['true_'+str(i) for i in range(1,rolling_days+1)] 
  scaler_input = np.concatenate([x_scaled, y_scaled], axis=1)
  scaler_output = scaler.inverse_transform(scaler_input)
  df_true = pd.DataFrame(scaler_output[:, timesteps:],columns=true_cols)    
  df_true.index = dataset.index
  
  return df_true, df_pred

# %% [markdown]
# **Prediction for a given date**

# %%
def prediction(start_dt, df_true, df_pred):
  
  end_date= start_dt + datetime.timedelta(rolling_days - 1 )
  idx = pd.date_range(start=start_dt, end=end_date)
  dt_pred = df_pred.loc[start_dt]
  dt_pred.index = idx
  dt_true = df_true.loc[start_dt]
  dt_true.index = idx
  results = pd.concat([dt_true,dt_pred], axis=1)
  results.columns=['Original','Predicted']
  
  return results

# %% [markdown]
# **MAPE Function**

# %%
def mean_absolute_percentage_error(y_pred, y_true): 
    return np.mean(np.abs((y_pred - y_true)) / (y_pred+ 1e-7)) * 100

# %% [markdown]
# **Inference plots and Evaluation Metrics**

# %%
df_true, df_pred = inverse_transform_out(from_model=model_from_file)

# %%
results = prediction(datetime.datetime(2019,3,4), df_true, df_pred)

# %%
configure_plotly_browser_state()
plotly_df(results, title="Predictions")
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div id="2fb8e798-a4de-4f69-bc0a-7946cf3f5fc3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot
22", "2017-10-23", "2017-10-24", "2017-10-25", "2017-10-26", "2017-10-27", "2017-10-28", "2017-10-29", "2017-10-30", "2017-10-31", "2017-11-01", "2017-11-02", "2017-11-03", "2017-11-04", "2017-11-05", "2017-11-06", "2017-11-07", "2017-11-08", "2017-11-09", "2017-11-10", "2017-11-11", "2017-11-12", "2017-11-13", "2017-11-14", "2017-11-15", "2017-11-16", "2017-11-17", "2017-11-18", "2017-11-19", "2017-11-20", "2017-11-21", "2017-11-22", "2017-11-23", "2017-11-24", "2017-11-25", "2017-11-26", "2017-11-27", "2017-11-28", "2017-11-29", "2017-11-30", "2017-12-01", "2017-12-02", "2017-12-03", "2017-12-04", "2017-12-05", "2017-12-06", "2017-12-07", "2017-12-08", "2017-12-09", "2017-12-10", "2017-12-11", "2017-12-12", "2017-12-13", "2017-12-14", "2017-12-15", "2017-12-16", "2017-12-17", "2017-12-18", "2017-12-19", "2017-12-20", "2017-12-21", "2017-12-22", "2017-12-23", "2017-12-24", "2017-12-25", "2017-12-26", "2017-12-27", "2017-12-28", "2017-12-29", "2017-12-30", "2017-12-31", "2018-01-01", "2018-01-02", "2018-01-03", "2018-01-04", "2018-01-05", "2018-01-06", "2018-01-07", "2018-01-08", "2018-01-09", "2018-01-10", "2018-01-11", "2018-01-12", "2018-01-13", "2018-01-14", "2018-01-15", "2018-01-16", "2018-01-17", "2018-01-18", "2018-01-19", "2018-01-20", "2018-01-21", "2018-01-22", "2018-01-23", "2018-01-24", "2018-01-25", "2018-01-26", "2018-01-27", "2018-01-28", "2018-01-29", "2018-01-30", "2018-01-31", "2018-02-01", "2018-02-02", "2018-02-03", "2018-02-04", "2018-02-05", "2018-02-06", "2018-02-07", "2018-02-08", "2018-02-09", "2018-02-10", "2018-02-11", "2018-02-12", "2018-02-13", "2018-02-14", "2018-02-15", "2018-02-16", "2018-02-17", "2018-02-18", "2018-02-19", "2018-02-20", "2018-02-21", "2018-02-22", "2018-02-23", "2018-02-24", "2018-02-25", "2018-02-26", "2018-02-27", "2018-02-28", "2018-03-01", "2018-03-02", "2018-03-03", "2018-03-04", "2018-03-05", "2018-03-06", "2018-03-07", "2018-03-08", "2018-03-09", "2018-03-10", "2018-03-11", "2018-03-12", "2018-03-13", "2018-03-14", "2018-03-15", "2018-03-16", "2018-03-17", "2018-03-18", "2018-03-19", "2018-03-20", "2018-03-21", "2018-03-22", "2018-03-23", "2018-03-24", "2018-03-25", "2018-03-26", "2018-03-27", "2018-03-28", "2018-03-29" ...

# %%
rmse = math.sqrt(mean_squared_error(results['Original'].values, results['Predicted'].values))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 438922.455

# %%
mape = mean_absolute_percentage_error(np.array(results['Predicted'].values),np.array(results['Original'].values))
print ('Test MAPE: %.3f' %mape)
# Out:
# Test MAPE: 10.308

# %%
err = (abs(sum(results['Predicted'].values) - sum(results['Original'].values)) / (sum(results['Original'].values))) *100
print ('Prediction Error: %.2f%%' %err)
# Out:
# Prediction Error: 2.55%
